# %%
import openai
from dotenv import dotenv_values
config = dotenv_values("../.env")
openai.api_key = config["OPENAI_API_KEY"]

# %%
import pandas as pd
import numpy as np
from tenacity import retry, wait_random_exponential, stop_after_attempt
import pickle
import tiktoken

# %% [markdown]
# ## Load The Movie Data

# %%
#dataset_path = "./movie_plots.csv"
dataset_path = "wiki_movie_plots_deduped.csv"
df = pd.read_csv(dataset_path)

# %%
# Narrow our data set to 5000 recent American movies (to save money)
movies = df[df["Origin/Ethnicity"] == "American"].sort_values("Release Year", ascending=False).head(5000)

# %%
# Extract the movie plots into a list
movie_plots = movies["Plot"].values

# %% [markdown]
# ## Generating The Embeddings

# %%
@retry(wait=wait_random_exponential(min=1, max=20), stop=stop_after_attempt(6))
def get_embedding(text, model="text-embedding-ada-002"):

    # replace newlines, which can negatively affect performance.
    text = text.replace("\n", " ")

    return openai.Embedding.create(input=text, model=model)["data"][0]["embedding"]

# %%
enc = tiktoken.encoding_for_model("text-embedding-ada-002")

# %%
total_tokens = sum([len(enc.encode(plot)) for plot in movie_plots])

# %%
total_tokens
cost = total_tokens * (.0004 / 1000)
print(f"Estimated cost ${cost:.2f}")
# Out:
# Estimated cost $1.45

# %%
# establish a cache of embeddings to avoid recomputing
# cache is a dict of tuples (text, model) -> embedding, saved as a pickle file

# set path to embedding cache
embedding_cache_path = "movie_embeddings_cache2.pkl"

# load the cache if it exists, and save a copy to disk
try:
    embedding_cache = pd.read_pickle(embedding_cache_path)
except FileNotFoundError:
    embedding_cache = {}
with open(embedding_cache_path, "wb") as embedding_cache_file:
    pickle.dump(embedding_cache, embedding_cache_file)

# define a function to retrieve embeddings from the cache if present, and otherwise request via the API
def embedding_from_string(string,
                          model="text-embedding-ada-002",
                          embedding_cache=embedding_cache):
    
    """Return embedding of given string, using a cache to avoid recomputing."""
    if (string, model) not in embedding_cache.keys():
        embedding_cache[(string, model)] = get_embedding(string, model)
        print(f"GOT EMBEDDING FROM OPENAI FOR {string[:20]}")
        with open(embedding_cache_path, "wb") as embedding_cache_file:
            pickle.dump(embedding_cache, embedding_cache_file)
    return embedding_cache[(string, model)]

# %%
# This line actaully generates the embeddings
plot_embeddings = [embedding_from_string(plot, model="text-embedding-ada-002") for plot in movie_plots]
# Out:
# GOT EMBEDDING FROM OPENAI FOR In 1933, a boy named
# GOT EMBEDDING FROM OPENAI FOR In Salem, Massachuse
# GOT EMBEDDING FROM OPENAI FOR The movie begins as
# GOT EMBEDDING FROM OPENAI FOR In 1970, 20-year-old
# GOT EMBEDDING FROM OPENAI FOR During the Bosnian W
# GOT EMBEDDING FROM OPENAI FOR Dave Lizewski, bored
# GOT EMBEDDING FROM OPENAI FOR Ellie Klug is a musi
# GOT EMBEDDING FROM OPENAI FOR A suicide bomber det
# GOT EMBEDDING FROM OPENAI FOR After losing her ban
# GOT EMBEDDING FROM OPENAI FOR In 1986, Lorraine La
# GOT EMBEDDING FROM OPENAI FOR Salesmen Billy McMah
# GOT EMBEDDING FROM OPENAI FOR At a New Year's Eve
# GOT EMBEDDING FROM OPENAI FOR Four couples gather
# GOT EMBEDDING FROM OPENAI FOR After climbing a gia
# GOT EMBEDDING FROM OPENAI FOR In the Kingdom of Cl
# GOT EMBEDDING FROM OPENAI FOR After winning $10,00
# GOT EMBEDDING FROM OPENAI FOR Kevin is throwing a
# GOT EMBEDDING FROM OPENAI FOR The film is set in 1
# GOT EMBEDDING FROM OPENAI FOR The film opens in 20
# GOT EMBEDDING FROM OPENAI FOR David Wong, a slacke
# GOT EMBEDDING FROM OPENAI FOR Joe Ransom is a fore
# GOT EMBEDDING FROM OPENAI FOR A backwoods communit
# GOT EMBEDDING FROM OPENAI FOR While visiting his m
# GOT EMBEDDING FROM OPENAI FOR The sequel to Never
# GOT EMBEDDING FROM OPENAI FOR In Afghanistan, Tali
# GOT EMBEDDING FROM OPENAI FOR Billy is sitting in
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Parker (Jason Statha
# GOT EMBEDDING FROM OPENAI FOR In 1905 Kansas, Osca
# GOT EMBEDDING FROM OPENAI FOR In 2013, huge alien
# GOT EMBEDDING FROM OPENAI FOR The film follows Tom
# GOT EMBEDDING FROM OPENAI FOR In 1995, schemer Dan
# GOT EMBEDDING FROM OPENAI FOR Lamb Mannerhelm (Jul
# GOT EMBEDDING FROM OPENAI FOR Adam Cassidy is a lo
# GOT EMBEDDING FROM OPENAI FOR With all the picture
# GOT EMBEDDING FROM OPENAI FOR Parkland weaves toge
# GOT EMBEDDING FROM OPENAI FOR Former Army Ranger M
# GOT EMBEDDING FROM OPENAI FOR An old gangster, wit
# GOT EMBEDDING FROM OPENAI FOR Sara Taylor is a pho
# GOT EMBEDDING FROM OPENAI FOR While in Camp Half-B
# GOT EMBEDDING FROM OPENAI FOR London based journal
# GOT EMBEDDING FROM OPENAI FOR In 1997, Luke Glanto
# GOT EMBEDDING FROM OPENAI FOR Machete Cortez (Dann
# GOT EMBEDDING FROM OPENAI FOR Dusty Crophopper is
# GOT EMBEDDING FROM OPENAI FOR After getting off wo
# GOT EMBEDDING FROM OPENAI FOR Captain Dmitri "Demi
# GOT EMBEDDING FROM OPENAI FOR In 1993, alcoholic a
# GOT EMBEDDING FROM OPENAI FOR New York City teenag
# GOT EMBEDDING FROM OPENAI FOR While investigating
# GOT EMBEDDING FROM OPENAI FOR In Atlanta, Georgia
# GOT EMBEDDING FROM OPENAI FOR With Krypton destabi
# GOT EMBEDDING FROM OPENAI FOR When a businessman's
# GOT EMBEDDING FROM OPENAI FOR Amid aerial footage
# GOT EMBEDDING FROM OPENAI FOR Michael "Mike" Wazow
# GOT EMBEDDING FROM OPENAI FOR Jake Carter (The Miz
# GOT EMBEDDING FROM OPENAI FOR Movie 43 is a series
# GOT EMBEDDING FROM OPENAI FOR While traveling cros
# GOT EMBEDDING FROM OPENAI FOR In 2077, sixty years
# GOT EMBEDDING FROM OPENAI FOR Four stage magicians
# GOT EMBEDDING FROM OPENAI FOR Alicia (Juno Temple)
# GOT EMBEDDING FROM OPENAI FOR The plot of the film
# GOT EMBEDDING FROM OPENAI FOR In Billings, Montana
# GOT EMBEDDING FROM OPENAI FOR Two 14-year-old boys
# GOT EMBEDDING FROM OPENAI FOR It is 2006, and 19-y
# GOT EMBEDDING FROM OPENAI FOR Sandra, manager of a
# GOT EMBEDDING FROM OPENAI FOR Chris Farraday (Mark
# GOT EMBEDDING FROM OPENAI FOR 12-year old Ida Clay
# GOT EMBEDDING FROM OPENAI FOR Zack (Haas) is a you
# GOT EMBEDDING FROM OPENAI FOR A mixed-blood Native
# GOT EMBEDDING FROM OPENAI FOR Eight years after th
# GOT EMBEDDING FROM OPENAI FOR Newly transferred co
# GOT EMBEDDING FROM OPENAI FOR Swanson (Tim Heideck
# GOT EMBEDDING FROM OPENAI FOR In 1760, the Collins
# GOT EMBEDDING FROM OPENAI FOR Casper Galloway, an
# GOT EMBEDDING FROM OPENAI FOR Beth Winter (Keaton)
# GOT EMBEDDING FROM OPENAI FOR Kate is a shark expe
# GOT EMBEDDING FROM OPENAI FOR In February 2012, Se
# GOT EMBEDDING FROM OPENAI FOR Arkansas, November 1
# GOT EMBEDDING FROM OPENAI FOR Teenager Elena Peter
# GOT EMBEDDING FROM OPENAI FOR Will Shaw (Henry Cav
# GOT EMBEDDING FROM OPENAI FOR In the Chatham Islan
# GOT EMBEDDING FROM OPENAI FOR The film is about a
# GOT EMBEDDING FROM OPENAI FOR The Citizen integrat
# GOT EMBEDDING FROM OPENAI FOR Strange electrical c
# GOT EMBEDDING FROM OPENAI FOR The film takes place
# GOT EMBEDDING FROM OPENAI FOR Oscar is the nicknam
# GOT EMBEDDING FROM OPENAI FOR Chris (Jesse McCartn
# GOT EMBEDDING FROM OPENAI FOR In 1987, an 8-year-o
# GOT EMBEDDING FROM OPENAI FOR Darrell, played by a
# GOT EMBEDDING FROM OPENAI FOR Celeste (Rashida Jon
# GOT EMBEDDING FROM OPENAI FOR Young newsparer repo
# GOT EMBEDDING FROM OPENAI FOR Armando Álvarez (Wil
# GOT EMBEDDING FROM OPENAI FOR After a casino heist
# GOT EMBEDDING FROM OPENAI FOR For their vacation,
# GOT EMBEDDING FROM OPENAI FOR Death Race owner R.H
# GOT EMBEDDING FROM OPENAI FOR Detachment is a chro
# GOT EMBEDDING FROM OPENAI FOR Democratic Congressm
# GOT EMBEDDING FROM OPENAI FOR Joby Taylor (Paul Da
# GOT EMBEDDING FROM OPENAI FOR After Lauren is dump
# GOT EMBEDDING FROM OPENAI FOR Airline pilot Captai
# GOT EMBEDDING FROM OPENAI FOR Toby (Clint Black) c
# GOT EMBEDDING FROM OPENAI FOR Tom Solomon (Jason S
# GOT EMBEDDING FROM OPENAI FOR The seven adult sibl
# GOT EMBEDDING FROM OPENAI FOR Dave, a senior in hi
# GOT EMBEDDING FROM OPENAI FOR Following a grueling
# GOT EMBEDDING FROM OPENAI FOR Two clownfish, Marli
# GOT EMBEDDING FROM OPENAI FOR Tom, a scientist, in
# GOT EMBEDDING FROM OPENAI FOR The Expendables—lead
# GOT EMBEDDING FROM OPENAI FOR James (Jameel Saleem
# GOT EMBEDDING FROM OPENAI FOR Pauline is a disturb
# GOT EMBEDDING FROM OPENAI FOR Brian Taylor and Mig
# GOT EMBEDDING FROM OPENAI FOR When the mother of h
# GOT EMBEDDING FROM OPENAI FOR When Santa leaves an
# GOT EMBEDDING FROM OPENAI FOR Nine people board an
# GOT EMBEDDING FROM OPENAI FOR Hyun Jae, or Jae for
# GOT EMBEDDING FROM OPENAI FOR Zack (Chris Salvator
# GOT EMBEDDING FROM OPENAI FOR The unexpected death
# GOT EMBEDDING FROM OPENAI FOR St. Jude Square is a
# GOT EMBEDDING FROM OPENAI FOR In Los Angeles, Cali
# GOT EMBEDDING FROM OPENAI FOR The film is about tw
# GOT EMBEDDING FROM OPENAI FOR In 1858 Texas, the S
# GOT EMBEDDING FROM OPENAI FOR For years, the ficti
# GOT EMBEDDING FROM OPENAI FOR The Heffley family a
# GOT EMBEDDING FROM OPENAI FOR On October 30, 1989,
# GOT EMBEDDING FROM OPENAI FOR High school student
# GOT EMBEDDING FROM OPENAI FOR The film’s opening c
# GOT EMBEDDING FROM OPENAI FOR On November 4, 1979,
# GOT EMBEDDING FROM OPENAI FOR Robert Carlyle plays
# GOT EMBEDDING FROM OPENAI FOR Frank Vega (Danny Tr
# GOT EMBEDDING FROM OPENAI FOR The Asgardian Loki e
# GOT EMBEDDING FROM OPENAI FOR David Hargrove (Bria
# GOT EMBEDDING FROM OPENAI FOR Dagny Taggart pilots
# GOT EMBEDDING FROM OPENAI FOR Twelve-year-old Gret
# GOT EMBEDDING FROM OPENAI FOR Sixty-year-old magna
# GOT EMBEDDING FROM OPENAI FOR On May 21, 1973, six
# GOT EMBEDDING FROM OPENAI FOR Rudy Donatello (Alan
# GOT EMBEDDING FROM OPENAI FOR Thirteen years after
# GOT EMBEDDING FROM OPENAI FOR A young Peter Parker
# GOT EMBEDDING FROM OPENAI FOR As a zombie apocalyp
# GOT EMBEDDING FROM OPENAI FOR The plot follows the
# GOT EMBEDDING FROM OPENAI FOR In October 2004, a N
# GOT EMBEDDING FROM OPENAI FOR In 2011, a group of
# GOT EMBEDDING FROM OPENAI FOR Dr. Alex Cross (Tyle
# GOT EMBEDDING FROM OPENAI FOR After a major electr
# GOT EMBEDDING FROM OPENAI FOR When mob boss Bellav
# GOT EMBEDDING FROM OPENAI FOR In 2012, Ana, a fail
# GOT EMBEDDING FROM OPENAI FOR In the Philippines,
# GOT EMBEDDING FROM OPENAI FOR In 1818, Abraham Lin
# GOT EMBEDDING FROM OPENAI FOR After his mother Nan
# GOT EMBEDDING FROM OPENAI FOR Angelina (Hinshaw) i
# GOT EMBEDDING FROM OPENAI FOR When a massive tecto
# GOT EMBEDDING FROM OPENAI FOR Two brothers (Charli
# GOT EMBEDDING FROM OPENAI FOR A novelist and a cor
# GOT EMBEDDING FROM OPENAI FOR In 2005, scholarly s
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Joshua Mason (Josh H
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR A SWAT team barges i
# GOT EMBEDDING FROM OPENAI FOR In a high tech under
# GOT EMBEDDING FROM OPENAI FOR A year after the eve
# GOT EMBEDDING FROM OPENAI FOR The film takes place
# GOT EMBEDDING FROM OPENAI FOR A teens life is shat
# GOT EMBEDDING FROM OPENAI FOR One night, a young m
# GOT EMBEDDING FROM OPENAI FOR In Medieval Scotland
# GOT EMBEDDING FROM OPENAI FOR In early 1980s Sovie
# GOT EMBEDDING FROM OPENAI FOR Jeremy Reins, a U.S.
# GOT EMBEDDING FROM OPENAI FOR Six weeks after Jaso
# GOT EMBEDDING FROM OPENAI FOR Stone portrays journ
# GOT EMBEDDING FROM OPENAI FOR On a normal day at a
# GOT EMBEDDING FROM OPENAI FOR Scooby-Doo and the g
# GOT EMBEDDING FROM OPENAI FOR In small town Alaska
# GOT EMBEDDING FROM OPENAI FOR A detective searchin
# GOT EMBEDDING FROM OPENAI FOR After their wedding
# GOT EMBEDDING FROM OPENAI FOR In small-town Cartha
# GOT EMBEDDING FROM OPENAI FOR Detective Nick Blade
# GOT EMBEDDING FROM OPENAI FOR Ben Banks, the 28-ye
# GOT EMBEDDING FROM OPENAI FOR Nick Flynn (Dano) is
# GOT EMBEDDING FROM OPENAI FOR Every day Alex wakes
# GOT EMBEDDING FROM OPENAI FOR One winter's night,
# GOT EMBEDDING FROM OPENAI FOR As a storm approache
# GOT EMBEDDING FROM OPENAI FOR Following the legali
# GOT EMBEDDING FROM OPENAI FOR The movie explains t
# GOT EMBEDDING FROM OPENAI FOR In 2005, the Gliese
# GOT EMBEDDING FROM OPENAI FOR After a zombie apoca
# GOT EMBEDDING FROM OPENAI FOR Barricade tells the
# GOT EMBEDDING FROM OPENAI FOR Two young campers wa
# GOT EMBEDDING FROM OPENAI FOR During summertime, M
# GOT EMBEDDING FROM OPENAI FOR In Tel Aviv, 1973, y
# GOT EMBEDDING FROM OPENAI FOR Marley Corbett is a
# GOT EMBEDDING FROM OPENAI FOR The B-17F Lucky Lass
# GOT EMBEDDING FROM OPENAI FOR A year after the mas
# GOT EMBEDDING FROM OPENAI FOR While admiring a ros
# GOT EMBEDDING FROM OPENAI FOR Kate Hannah (Mary El
# GOT EMBEDDING FROM OPENAI FOR True crime writer El
# GOT EMBEDDING FROM OPENAI FOR After eight months o
# GOT EMBEDDING FROM OPENAI FOR A young woman named
# GOT EMBEDDING FROM OPENAI FOR Heather Mason (Adela
# GOT EMBEDDING FROM OPENAI FOR In Berkeley, Califor
# GOT EMBEDDING FROM OPENAI FOR In New York City, a
# GOT EMBEDDING FROM OPENAI FOR Best friends Chon (T
# GOT EMBEDDING FROM OPENAI FOR Darius Britt (Aubrey
# GOT EMBEDDING FROM OPENAI FOR In Cape Town, South
# GOT EMBEDDING FROM OPENAI FOR Ex-cop and cage figh
# GOT EMBEDDING FROM OPENAI FOR Calvin Weir-Fields (
# GOT EMBEDDING FROM OPENAI FOR In 1987, Sherrie Chr
# GOT EMBEDDING FROM OPENAI FOR Set in the near futu
# GOT EMBEDDING FROM OPENAI FOR Jack Frost awakens f
# GOT EMBEDDING FROM OPENAI FOR Alice and the others
# GOT EMBEDDING FROM OPENAI FOR In 2011, Anse Rainie
# GOT EMBEDDING FROM OPENAI FOR In 1944, as the air
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR An introductory mont
# GOT EMBEDDING FROM OPENAI FOR In 19th-century Balt
# GOT EMBEDDING FROM OPENAI FOR The film opens as Lo
# GOT EMBEDDING FROM OPENAI FOR Ozu, the villain fro
# GOT EMBEDDING FROM OPENAI FOR As a spacecraft depa
# GOT EMBEDDING FROM OPENAI FOR In Pasadena, high sc
# GOT EMBEDDING FROM OPENAI FOR Pete Cozy (Eric Mabi
# GOT EMBEDDING FROM OPENAI FOR The film has a nonli
# GOT EMBEDDING FROM OPENAI FOR A newly separated co
# GOT EMBEDDING FROM OPENAI FOR In Los Angeles, subs
# GOT EMBEDDING FROM OPENAI FOR Detroit, Michigan: 1
# GOT EMBEDDING FROM OPENAI FOR The Trade Federation
# GOT EMBEDDING FROM OPENAI FOR An aging Atlanta Bra
# GOT EMBEDDING FROM OPENAI FOR Maya is a U.S. Centr
# GOT EMBEDDING FROM OPENAI FOR When Matt moved to H
# GOT EMBEDDING FROM OPENAI FOR When Litwak's Family
# GOT EMBEDDING FROM OPENAI FOR Perseus (Sam Worthin
# GOT EMBEDDING FROM OPENAI FOR Clayton Hammond (Den
# GOT EMBEDDING FROM OPENAI FOR Set in Atlanta,[4] t
# GOT EMBEDDING FROM OPENAI FOR In the town of Glenv
# GOT EMBEDDING FROM OPENAI FOR George and Linda Ger
# GOT EMBEDDING FROM OPENAI FOR Paige Collins (Rache
# GOT EMBEDDING FROM OPENAI FOR In a small town, men
# GOT EMBEDDING FROM OPENAI FOR The film is presente
# GOT EMBEDDING FROM OPENAI FOR A few years after th
# GOT EMBEDDING FROM OPENAI FOR The setting begins w
# GOT EMBEDDING FROM OPENAI FOR The film starts on O
# GOT EMBEDDING FROM OPENAI FOR At the end of the 21
# GOT EMBEDDING FROM OPENAI FOR In 1996, treasure hu
# GOT EMBEDDING FROM OPENAI FOR Brian is a 16-year-o
# GOT EMBEDDING FROM OPENAI FOR The film is composed
# GOT EMBEDDING FROM OPENAI FOR CIA agents and best
# GOT EMBEDDING FROM OPENAI FOR While having sex in
# GOT EMBEDDING FROM OPENAI FOR The film follows fou
# GOT EMBEDDING FROM OPENAI FOR In 1984, middle scho
# GOT EMBEDDING FROM OPENAI FOR In 1985, eight-year-
# GOT EMBEDDING FROM OPENAI FOR Julia lives in a sma
# GOT EMBEDDING FROM OPENAI FOR At the funeral of hi
# GOT EMBEDDING FROM OPENAI FOR Princess Odette and
# GOT EMBEDDING FROM OPENAI FOR In New Orleans, Will
# GOT EMBEDDING FROM OPENAI FOR At the 2011 ICCA Fin
# GOT EMBEDDING FROM OPENAI FOR Jack McCall (Eddie M
# GOT EMBEDDING FROM OPENAI FOR The film is set agai
# GOT EMBEDDING FROM OPENAI FOR Jesse Fischer (Radno
# GOT EMBEDDING FROM OPENAI FOR As the Fugue String
# GOT EMBEDDING FROM OPENAI FOR In West Dallas, Texa
# GOT EMBEDDING FROM OPENAI FOR In 1998, Erik, a Dan
# GOT EMBEDDING FROM OPENAI FOR After the untimely d
# GOT EMBEDDING FROM OPENAI FOR It has been four yea
# GOT EMBEDDING FROM OPENAI FOR In 1881, Edgar Rice
# GOT EMBEDDING FROM OPENAI FOR Jeff (Segel) is a 30
# GOT EMBEDDING FROM OPENAI FOR In Pittsburgh, Penns
# GOT EMBEDDING FROM OPENAI FOR While Scrat inadvert
# GOT EMBEDDING FROM OPENAI FOR As punishment for a
# GOT EMBEDDING FROM OPENAI FOR A newly divorced med
# GOT EMBEDDING FROM OPENAI FOR In 1895, in the afte
# GOT EMBEDDING FROM OPENAI FOR Although a devoted c
# GOT EMBEDDING FROM OPENAI FOR Charlie Bronson (Dax
# GOT EMBEDDING FROM OPENAI FOR High school valedict
# GOT EMBEDDING FROM OPENAI FOR In the 1980s, a girl
# GOT EMBEDDING FROM OPENAI FOR Former Division I co
# GOT EMBEDDING FROM OPENAI FOR Former Marine Mallor
# GOT EMBEDDING FROM OPENAI FOR Andy Brewster (Seth
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Jillian "Jill" Conwa
# GOT EMBEDDING FROM OPENAI FOR Frank Murdoch (Joel
# GOT EMBEDDING FROM OPENAI FOR Grace is a single mo
# GOT EMBEDDING FROM OPENAI FOR In Romania, a French
# GOT EMBEDDING FROM OPENAI FOR Jenn (played by Jenn
# GOT EMBEDDING FROM OPENAI FOR British art curator
# GOT EMBEDDING FROM OPENAI FOR In Cleveland, Ohio,[
# GOT EMBEDDING FROM OPENAI FOR Jason (an advertisin
# GOT EMBEDDING FROM OPENAI FOR Sam Harper (Chris Pi
# GOT EMBEDDING FROM OPENAI FOR In 1931, the Bondura
# GOT EMBEDDING FROM OPENAI FOR John Ottway (Liam Ne
# GOT EMBEDDING FROM OPENAI FOR In Canada, novelist
# GOT EMBEDDING FROM OPENAI FOR Freddie Quell is a W
# GOT EMBEDDING FROM OPENAI FOR When her husband tel
# GOT EMBEDDING FROM OPENAI FOR In January 1865, Pre
# GOT EMBEDDING FROM OPENAI FOR Artie Decker, a spor
# GOT EMBEDDING FROM OPENAI FOR In the small town of
# GOT EMBEDDING FROM OPENAI FOR On October 9, 2006,
# GOT EMBEDDING FROM OPENAI FOR Anita (Macy Gray), t
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Stephanie Plum, out
# GOT EMBEDDING FROM OPENAI FOR The film is told fro
# GOT EMBEDDING FROM OPENAI FOR  23-year-old Martine
# GOT EMBEDDING FROM OPENAI FOR In September 1965, o
# GOT EMBEDDING FROM OPENAI FOR The city of Monstrop
# GOT EMBEDDING FROM OPENAI FOR Snow White's widowed
# GOT EMBEDDING FROM OPENAI FOR In 2012, an alien cr
# GOT EMBEDDING FROM OPENAI FOR The story is narrate
# GOT EMBEDDING FROM OPENAI FOR In nineteenth centur
# GOT EMBEDDING FROM OPENAI FOR Many days after bidd
# GOT EMBEDDING FROM OPENAI FOR In 2079, CIA agent S
# GOT EMBEDDING FROM OPENAI FOR Young scientist Vict
# GOT EMBEDDING FROM OPENAI FOR In New York City, Ni
# GOT EMBEDDING FROM OPENAI FOR Alex (Gael Garcia Be
# GOT EMBEDDING FROM OPENAI FOR In 2044, 25-year-old
# GOT EMBEDDING FROM OPENAI FOR Logan Thibault (Zac
# GOT EMBEDDING FROM OPENAI FOR Ted Wiggins is a 12-
# GOT EMBEDDING FROM OPENAI FOR George Needleman, a
# GOT EMBEDDING FROM OPENAI FOR Mike (Channing Tatum
# GOT EMBEDDING FROM OPENAI FOR Monte Wildhorn (Free
# GOT EMBEDDING FROM OPENAI FOR Maladies is divided
# GOT EMBEDDING FROM OPENAI FOR British medical stud
# GOT EMBEDDING FROM OPENAI FOR Jamie Rellis (Mila K
# GOT EMBEDDING FROM OPENAI FOR Britt Reid is the pl
# GOT EMBEDDING FROM OPENAI FOR Eric (Jason Sudeikis
# GOT EMBEDDING FROM OPENAI FOR In Stratford-Upon-Av
# GOT EMBEDDING FROM OPENAI FOR In Stockholm, Sweden
# GOT EMBEDDING FROM OPENAI FOR Billions of years ag
# GOT EMBEDDING FROM OPENAI FOR The story involves a
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Charley Brewster is
# GOT EMBEDDING FROM OPENAI FOR Salesman Nick Halsey
# GOT EMBEDDING FROM OPENAI FOR After a long night o
# GOT EMBEDDING FROM OPENAI FOR Sam Lawton is on his
# GOT EMBEDDING FROM OPENAI FOR When Dominic "Dom" T
# GOT EMBEDDING FROM OPENAI FOR Nine-year-old Oskar
# GOT EMBEDDING FROM OPENAI FOR In the year AD 140,
# GOT EMBEDDING FROM OPENAI FOR In New Orleans, Dyla
# GOT EMBEDDING FROM OPENAI FOR John Milton (Nicolas
# GOT EMBEDDING FROM OPENAI FOR Two years after the
# GOT EMBEDDING FROM OPENAI FOR In 2007, Will Atento
# GOT EMBEDDING FROM OPENAI FOR An unnamed mechanic
# GOT EMBEDDING FROM OPENAI FOR Rick (Owen Wilson) a
# GOT EMBEDDING FROM OPENAI FOR Former college frien
# GOT EMBEDDING FROM OPENAI FOR Hanna Heller is a fi
# GOT EMBEDDING FROM OPENAI FOR Erik, son of the pen
# GOT EMBEDDING FROM OPENAI FOR  Homemade videos sho
# GOT EMBEDDING FROM OPENAI FOR Flashback: At Blackw
# GOT EMBEDDING FROM OPENAI FOR In 1919, after anarc
# GOT EMBEDDING FROM OPENAI FOR Married couple Josh
# GOT EMBEDDING FROM OPENAI FOR A.J., an ex-con who
# GOT EMBEDDING FROM OPENAI FOR In 2169, people are
# GOT EMBEDDING FROM OPENAI FOR Before the dawn of m
# GOT EMBEDDING FROM OPENAI FOR Stephen Meyers is th
# GOT EMBEDDING FROM OPENAI FOR John Smith is an ali
# GOT EMBEDDING FROM OPENAI FOR In 1931, 12-year-old
# GOT EMBEDDING FROM OPENAI FOR Nick Hendricks and D
# GOT EMBEDDING FROM OPENAI FOR On Easter Island, an
# GOT EMBEDDING FROM OPENAI FOR Wolf (Patrick Warbur
# GOT EMBEDDING FROM OPENAI FOR In the early Sixties
# GOT EMBEDDING FROM OPENAI FOR Following the loss o
# GOT EMBEDDING FROM OPENAI FOR In 1963, Aibileen Cl
# GOT EMBEDDING FROM OPENAI FOR A modern comedy abou
# GOT EMBEDDING FROM OPENAI FOR After burying Dobby,
# GOT EMBEDDING FROM OPENAI FOR A story of relations
# GOT EMBEDDING FROM OPENAI FOR Two FBI agents are c
# GOT EMBEDDING FROM OPENAI FOR Elizabeth Halsey is
# GOT EMBEDDING FROM OPENAI FOR Sawyer Nelson, a lon
# GOT EMBEDDING FROM OPENAI FOR Bella Swan is prepar
# GOT EMBEDDING FROM OPENAI FOR FBI agent Malcolm Tu
# GOT EMBEDDING FROM OPENAI FOR Carlos Galindo works
# GOT EMBEDDING FROM OPENAI FOR Walter Black (Mel Gi
# GOT EMBEDDING FROM OPENAI FOR Kyle Kingson (Alex P
# GOT EMBEDDING FROM OPENAI FOR On August 12, 2011,
# GOT EMBEDDING FROM OPENAI FOR In 2016, the United
# GOT EMBEDDING FROM OPENAI FOR On Christmas Eve, hu
# GOT EMBEDDING FROM OPENAI FOR Boozy Arthur Bach an
# GOT EMBEDDING FROM OPENAI FOR George (Freddie High
# GOT EMBEDDING FROM OPENAI FOR In December 1974, th
# GOT EMBEDDING FROM OPENAI FOR Rhoda Williams (Brit
# GOT EMBEDDING FROM OPENAI FOR African Cats, referr
# GOT EMBEDDING FROM OPENAI FOR Young journalist Tin
# GOT EMBEDDING FROM OPENAI FOR In 2006, Brooklyn Co
# GOT EMBEDDING FROM OPENAI FOR Nathan Harper (Taylo
# GOT EMBEDDING FROM OPENAI FOR Adam Lerner (Joseph
# GOT EMBEDDING FROM OPENAI FOR Marijuana-smoking, G
# GOT EMBEDDING FROM OPENAI FOR The film starts with
# GOT EMBEDDING FROM OPENAI FOR Sabrina Watson (Paul
# GOT EMBEDDING FROM OPENAI FOR The film follows thr
# GOT EMBEDDING FROM OPENAI FOR Annie Walker (Kriste
# GOT EMBEDDING FROM OPENAI FOR In 1987 in Oklahoma,
# GOT EMBEDDING FROM OPENAI FOR Bucky Larson (Nick S
# GOT EMBEDDING FROM OPENAI FOR Ronny (Vince Vaughn)
# GOT EMBEDDING FROM OPENAI FOR The Heffley family a
# GOT EMBEDDING FROM OPENAI FOR In 1987, Latif Yahia
# GOT EMBEDDING FROM OPENAI FOR Matthew "Matt" King
# GOT EMBEDDING FROM OPENAI FOR The year is 1997 and
# GOT EMBEDDING FROM OPENAI FOR Americans Ben and Se
# GOT EMBEDDING FROM OPENAI FOR Cal Weaver is a midd
# GOT EMBEDDING FROM OPENAI FOR In 1873 New Mexico T
# GOT EMBEDDING FROM OPENAI FOR When his truck is st
# GOT EMBEDDING FROM OPENAI FOR Returning from a Hon
# GOT EMBEDDING FROM OPENAI FOR On April 14, 1865, f
# GOT EMBEDDING FROM OPENAI FOR Conan is the son of
# GOT EMBEDDING FROM OPENAI FOR In 1992, in Bogota,
# GOT EMBEDDING FROM OPENAI FOR Ray Bradstone (Tripl
# GOT EMBEDDING FROM OPENAI FOR One evening, after g
# GOT EMBEDDING FROM OPENAI FOR Naive and idealistic
# GOT EMBEDDING FROM OPENAI FOR Finn McMissile, a Br
# GOT EMBEDDING FROM OPENAI FOR When two grade-schoo
# GOT EMBEDDING FROM OPENAI FOR In the present day,
# GOT EMBEDDING FROM OPENAI FOR The movie tells the
# GOT EMBEDDING FROM OPENAI FOR Dave, The Chipmunks,
# GOT EMBEDDING FROM OPENAI FOR In 1988, Daniel "Dan
# GOT EMBEDDING FROM OPENAI FOR In 1982, an alien sp
# GOT EMBEDDING FROM OPENAI FOR The film is set in 1
# GOT EMBEDDING FROM OPENAI FOR In 1979, Deputy Sher
# GOT EMBEDDING FROM OPENAI FOR Short-order cook Fra
# GOT EMBEDDING FROM OPENAI FOR In the 1960s,[9] a y
# GOT EMBEDDING FROM OPENAI FOR Scriptwriter David S
# GOT EMBEDDING FROM OPENAI FOR OSS agent Marissa Wi
# GOT EMBEDDING FROM OPENAI FOR U.S. Army pilot Capt
# GOT EMBEDDING FROM OPENAI FOR In 2003, teenager Be
# GOT EMBEDDING FROM OPENAI FOR In 2002, a young cop
# GOT EMBEDDING FROM OPENAI FOR Rachel White (Ginnif
# GOT EMBEDDING FROM OPENAI FOR In nineteenth centur
# GOT EMBEDDING FROM OPENAI FOR As the Smurfs get re
# GOT EMBEDDING FROM OPENAI FOR The story takes plac
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR In 1891, Irene Adler
# GOT EMBEDDING FROM OPENAI FOR Seven Tulane Univers
# GOT EMBEDDING FROM OPENAI FOR In Villach in the ye
# GOT EMBEDDING FROM OPENAI FOR On the fifteenth ann
# GOT EMBEDDING FROM OPENAI FOR Seventeen-year-old J
# GOT EMBEDDING FROM OPENAI FOR In Lagrange, Ohio, C
# GOT EMBEDDING FROM OPENAI FOR In 965 AD, Odin, kin
# GOT EMBEDDING FROM OPENAI FOR Sara Matthews (Minka
# GOT EMBEDDING FROM OPENAI FOR In Venice, the muske
# GOT EMBEDDING FROM OPENAI FOR The film follows the
# GOT EMBEDDING FROM OPENAI FOR A zookeeper named Gr
# GOT EMBEDDING FROM OPENAI FOR Thadeous and Fabious
# GOT EMBEDDING FROM OPENAI FOR Mavis Gary (Charlize
# GOT EMBEDDING FROM OPENAI FOR In 1944, in a Nazi d
# GOT EMBEDDING FROM OPENAI FOR Winnie-the-Pooh wake
# GOT EMBEDDING FROM OPENAI FOR Small-town New Provi
# GOT EMBEDDING FROM OPENAI FOR In Boston, Ally Darl
# GOT EMBEDDING FROM OPENAI FOR Benjamin Mee is stil
# GOT EMBEDDING FROM OPENAI FOR Dr. Thomas Avery (Ma
# GOT EMBEDDING FROM OPENAI FOR Charlie O'Brien, Cir
# GOT EMBEDDING FROM OPENAI FOR U.S. Marine Tommy Ri
# GOT EMBEDDING FROM OPENAI FOR Emma (Rachel Bilson)
# GOT EMBEDDING FROM OPENAI FOR Seven years after es
# GOT EMBEDDING FROM OPENAI FOR Dr. Martin Harris an
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR In 1961, the "Ark",
# GOT EMBEDDING FROM OPENAI FOR Josh Kovaks is the b
# GOT EMBEDDING FROM OPENAI FOR Paul Kemp is an auth
# GOT EMBEDDING FROM OPENAI FOR Homicide detectives
# GOT EMBEDDING FROM OPENAI FOR Michael Kovak (Colin
# GOT EMBEDDING FROM OPENAI FOR Shirley (Loretta Dev
# GOT EMBEDDING FROM OPENAI FOR Thomas Popper (Jim C
# GOT EMBEDDING FROM OPENAI FOR Grace Bennett (Selen
# GOT EMBEDDING FROM OPENAI FOR Oakland Athletics ge
# GOT EMBEDDING FROM OPENAI FOR IMF agent Trevor Han
# GOT EMBEDDING FROM OPENAI FOR In 2010, Gil Pender,
# GOT EMBEDDING FROM OPENAI FOR Arthur Bishop, worki
# GOT EMBEDDING FROM OPENAI FOR A young woman named
# GOT EMBEDDING FROM OPENAI FOR Unbeknownst to human
# GOT EMBEDDING FROM OPENAI FOR A 17-year-old Manhat
# GOT EMBEDDING FROM OPENAI FOR In South Sudan the L
# GOT EMBEDDING FROM OPENAI FOR Based on Oliver Sack
# GOT EMBEDDING FROM OPENAI FOR A young blonde woman
# GOT EMBEDDING FROM OPENAI FOR Criminal defense att
# GOT EMBEDDING FROM OPENAI FOR Eddie Morra is a str
# GOT EMBEDDING FROM OPENAI FOR Anna Gardner (Felici
# GOT EMBEDDING FROM OPENAI FOR Larry Crowne, a midd
# GOT EMBEDDING FROM OPENAI FOR Lord Shen, the scion
# GOT EMBEDDING FROM OPENAI FOR In 1980, mercenaries
# GOT EMBEDDING FROM OPENAI FOR Will Rodman, a scien
# GOT EMBEDDING FROM OPENAI FOR In 1960, Danny Green
# GOT EMBEDDING FROM OPENAI FOR Brothers Walter and
# GOT EMBEDDING FROM OPENAI FOR An unnamed investmen
# GOT EMBEDDING FROM OPENAI FOR After the death of h
# GOT EMBEDDING FROM OPENAI FOR A centuries long war
# GOT EMBEDDING FROM OPENAI FOR In Brazil, various e
# GOT EMBEDDING FROM OPENAI FOR On New Year's Eve, V
# GOT EMBEDDING FROM OPENAI FOR A young man, Enoch,
# GOT EMBEDDING FROM OPENAI FOR Travis (Michael Anga
# GOT EMBEDDING FROM OPENAI FOR Valerie is a young w
# GOT EMBEDDING FROM OPENAI FOR In 2020, human boxer
# GOT EMBEDDING FROM OPENAI FOR A pet chameleon (Joh
# GOT EMBEDDING FROM OPENAI FOR Mike Weiss is a youn
# GOT EMBEDDING FROM OPENAI FOR It's time for the an
# GOT EMBEDDING FROM OPENAI FOR Puss in Boots (Anton
# GOT EMBEDDING FROM OPENAI FOR This film's story oc
# GOT EMBEDDING FROM OPENAI FOR Graeme Willy and Cli
# GOT EMBEDDING FROM OPENAI FOR After first meeting
# GOT EMBEDDING FROM OPENAI FOR Ned Rochlin (Paul Ru
# GOT EMBEDDING FROM OPENAI FOR In 2005, Katie deliv
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR At a dinner celebrat
# GOT EMBEDDING FROM OPENAI FOR Fugitive John Taylor
# GOT EMBEDDING FROM OPENAI FOR In the wilderness of
# GOT EMBEDDING FROM OPENAI FOR Deeply depressed at
# GOT EMBEDDING FROM OPENAI FOR In 1978, five childh
# GOT EMBEDDING FROM OPENAI FOR Florence Marr (Greta
# GOT EMBEDDING FROM OPENAI FOR On March 19, 2003, I
# GOT EMBEDDING FROM OPENAI FOR Minister of Magic Ru
# GOT EMBEDDING FROM OPENAI FOR Eighteen-year-old Be
# GOT EMBEDDING FROM OPENAI FOR Erin Langford (Drew
# GOT EMBEDDING FROM OPENAI FOR No one really knows
# GOT EMBEDDING FROM OPENAI FOR In 2009, British roc
# GOT EMBEDDING FROM OPENAI FOR The story is told in
# GOT EMBEDDING FROM OPENAI FOR The Expendables, a g
# GOT EMBEDDING FROM OPENAI FOR Childhood friends Da
# GOT EMBEDDING FROM OPENAI FOR A personal aide to t
# GOT EMBEDDING FROM OPENAI FOR Each woman is repres
# GOT EMBEDDING FROM OPENAI FOR In 1957, when second
# GOT EMBEDDING FROM OPENAI FOR Micky Ward is an Ame
# GOT EMBEDDING FROM OPENAI FOR Upon leaving prison,
# GOT EMBEDDING FROM OPENAI FOR Valerie Plame is emp
# GOT EMBEDDING FROM OPENAI FOR Brendan Fraser and K
# GOT EMBEDDING FROM OPENAI FOR A failed playwright,
# GOT EMBEDDING FROM OPENAI FOR Sam Gold (Jesse Eise
# GOT EMBEDDING FROM OPENAI FOR On assignment in Tha
# GOT EMBEDDING FROM OPENAI FOR After colliding with
# GOT EMBEDDING FROM OPENAI FOR Three estranged, dep
# GOT EMBEDDING FROM OPENAI FOR During the American
# GOT EMBEDDING FROM OPENAI FOR In Seattle, not far
# GOT EMBEDDING FROM OPENAI FOR Walter Krunk is a 35
# GOT EMBEDDING FROM OPENAI FOR After a break-up wit
# GOT EMBEDDING FROM OPENAI FOR In 1952, Deputy Sher
# GOT EMBEDDING FROM OPENAI FOR Nic (Annette Bening)
# GOT EMBEDDING FROM OPENAI FOR Dre Parker and his m
# GOT EMBEDDING FROM OPENAI FOR Smith is an 18-year-
# GOT EMBEDDING FROM OPENAI FOR Leslie Wright (Queen
# GOT EMBEDDING FROM OPENAI FOR Kate, Steve, Mick, a
# GOT EMBEDDING FROM OPENAI FOR Beavis and Butt-head
# GOT EMBEDDING FROM OPENAI FOR Softball player Lisa
# GOT EMBEDDING FROM OPENAI FOR Jack (Philip Seymour
# GOT EMBEDDING FROM OPENAI FOR After contemplating
# GOT EMBEDDING FROM OPENAI FOR In Russia, the media
# GOT EMBEDDING FROM OPENAI FOR Dominick "Dom" Cobb
# GOT EMBEDDING FROM OPENAI FOR In 2008, while rehea
# GOT EMBEDDING FROM OPENAI FOR Steven Jay Russell i
# GOT EMBEDDING FROM OPENAI FOR A woman named Gina (
# GOT EMBEDDING FROM OPENAI FOR This movie is based
# GOT EMBEDDING FROM OPENAI FOR The Isle of Berk is
# GOT EMBEDDING FROM OPENAI FOR At South Station, Bo
# GOT EMBEDDING FROM OPENAI FOR The story takes plac
# GOT EMBEDDING FROM OPENAI FOR Elizabeth Gilbert ha
# GOT EMBEDDING FROM OPENAI FOR Olive Penderghast, a
# GOT EMBEDDING FROM OPENAI FOR A hot shot Washingto
# GOT EMBEDDING FROM OPENAI FOR Emily Jenkins (Renée
# GOT EMBEDDING FROM OPENAI FOR Ali Rose (Aguilera)
# GOT EMBEDDING FROM OPENAI FOR On October 23, 2006,
# GOT EMBEDDING FROM OPENAI FOR Bobby "Carlo" Powers
# GOT EMBEDDING FROM OPENAI FOR Milo Boyd is a forme
# GOT EMBEDDING FROM OPENAI FOR Thirty years after a
# GOT EMBEDDING FROM OPENAI FOR The film is presente
# GOT EMBEDDING FROM OPENAI FOR Nina Sayers is a 28-
# GOT EMBEDDING FROM OPENAI FOR Sheriff Sugar Wolf (
# GOT EMBEDDING FROM OPENAI FOR Tyler, an aspiring a
# GOT EMBEDDING FROM OPENAI FOR Barry Munday (Patric
# GOT EMBEDDING FROM OPENAI FOR Zoe (Jennifer Lopez)
# GOT EMBEDDING FROM OPENAI FOR Jack, a gunsmith and
# GOT EMBEDDING FROM OPENAI FOR In Alberta, Canada's
# GOT EMBEDDING FROM OPENAI FOR In 1970s New York Ci
# GOT EMBEDDING FROM OPENAI FOR Troubled by a strang
# GOT EMBEDDING FROM OPENAI FOR Reverend Cotton Marc
# GOT EMBEDDING FROM OPENAI FOR Laura Pehlke (Jenna
# GOT EMBEDDING FROM OPENAI FOR John "Hannibal" Smit
# GOT EMBEDDING FROM OPENAI FOR Mountaineer Aron Ral
# GOT EMBEDDING FROM OPENAI FOR In Germany, a bloodh
# GOT EMBEDDING FROM OPENAI FOR Charlie St. Cloud is
# GOT EMBEDDING FROM OPENAI FOR Edmund and Lucy Peve
# GOT EMBEDDING FROM OPENAI FOR In 2019, a plague ha
# GOT EMBEDDING FROM OPENAI FOR Peter Highman (Rober
# GOT EMBEDDING FROM OPENAI FOR Tim Conrad is a mid-
# GOT EMBEDDING FROM OPENAI FOR The film starts with
# GOT EMBEDDING FROM OPENAI FOR Ramirez (Jacob Varga
# GOT EMBEDDING FROM OPENAI FOR Gru, a supervillain,
# GOT EMBEDDING FROM OPENAI FOR A funeral service is
# GOT EMBEDDING FROM OPENAI FOR While serving in the
# GOT EMBEDDING FROM OPENAI FOR Dylan (Stahl) tries
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Living on City Islan
# GOT EMBEDDING FROM OPENAI FOR Phil and Claire Fost
# GOT EMBEDDING FROM OPENAI FOR Jamie (Catherine Kee
# GOT EMBEDDING FROM OPENAI FOR Thomas Zelda (Tim Al
# GOT EMBEDDING FROM OPENAI FOR In the town of Ogden
# GOT EMBEDDING FROM OPENAI FOR Beau sings with Kell
# GOT EMBEDDING FROM OPENAI FOR James "Jimmy" Monroe
# GOT EMBEDDING FROM OPENAI FOR Betty Anne Waters' l
# GOT EMBEDDING FROM OPENAI FOR When the publicly he
# GOT EMBEDDING FROM OPENAI FOR In ancient times, af
# GOT EMBEDDING FROM OPENAI FOR 15-year-old Sokka an
# GOT EMBEDDING FROM OPENAI FOR Dave Lizewski is an
# GOT EMBEDDING FROM OPENAI FOR At seventeen, Veroni
# GOT EMBEDDING FROM OPENAI FOR  The year is 1199. R
# GOT EMBEDDING FROM OPENAI FOR Detectives Jack Well
# GOT EMBEDDING FROM OPENAI FOR 30-something Kassie
# GOT EMBEDDING FROM OPENAI FOR Young mother Madylyn
# GOT EMBEDDING FROM OPENAI FOR In New York City, Mo
# GOT EMBEDDING FROM OPENAI FOR Bob Ho is a CIA unde
# GOT EMBEDDING FROM OPENAI FOR Genetic engineers Cl
# GOT EMBEDDING FROM OPENAI FOR In 740 AD, in Englan
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR In October 2003, 19-
# GOT EMBEDDING FROM OPENAI FOR The subtle connectio
# GOT EMBEDDING FROM OPENAI FOR Jarrod and his girlf
# GOT EMBEDDING FROM OPENAI FOR In 1954, U.S. Marsha
# GOT EMBEDDING FROM OPENAI FOR Shrek has grown stea
# GOT EMBEDDING FROM OPENAI FOR Kirk Kettner is a TS
# GOT EMBEDDING FROM OPENAI FOR Carrie, Samantha, Ch
# GOT EMBEDDING FROM OPENAI FOR In 1969, Denver hous
# GOT EMBEDDING FROM OPENAI FOR In Toronto, 23-year-
# GOT EMBEDDING FROM OPENAI FOR Two men, Brad and Ry
# GOT EMBEDDING FROM OPENAI FOR Evelyn Salt (Angelin
# GOT EMBEDDING FROM OPENAI FOR A compulsive gambler
# GOT EMBEDDING FROM OPENAI FOR Cherie Currie (Dakot
# GOT EMBEDDING FROM OPENAI FOR Long ago, a drop of
# GOT EMBEDDING FROM OPENAI FOR Derek Thompson (Dway
# GOT EMBEDDING FROM OPENAI FOR A British woman, Eli
# GOT EMBEDDING FROM OPENAI FOR Successful and singl
# GOT EMBEDDING FROM OPENAI FOR Successful real esta
# GOT EMBEDDING FROM OPENAI FOR Shy, socially inept
# GOT EMBEDDING FROM OPENAI FOR Alfie (Anthony Hopki
# GOT EMBEDDING FROM OPENAI FOR In 2002, Marni Olsen
# GOT EMBEDDING FROM OPENAI FOR Yogi (Aykroyd) and B
# GOT EMBEDDING FROM OPENAI FOR Ben Singer (Matthew
# GOT EMBEDDING FROM OPENAI FOR In 1891, Ben Talbot
# GOT EMBEDDING FROM OPENAI FOR Seventeen-year-old R
# GOT EMBEDDING FROM OPENAI FOR The four couples pre
# GOT EMBEDDING FROM OPENAI FOR Seventeen-year-old A
# GOT EMBEDDING FROM OPENAI FOR When Ben Walker (Kev
# GOT EMBEDDING FROM OPENAI FOR Ever since the death
# GOT EMBEDDING FROM OPENAI FOR In 2001, Gordon Gekk
# GOT EMBEDDING FROM OPENAI FOR Becca Crane (Jenn Pr
# GOT EMBEDDING FROM OPENAI FOR The film follows a g
# GOT EMBEDDING FROM OPENAI FOR While moving a train
# GOT EMBEDDING FROM OPENAI FOR On the Upper East Si
# GOT EMBEDDING FROM OPENAI FOR Mattie Ross's father
# GOT EMBEDDING FROM OPENAI FOR In 1989, seven years
# GOT EMBEDDING FROM OPENAI FOR A group of seven col
# GOT EMBEDDING FROM OPENAI FOR Four lifelong friend
# GOT EMBEDDING FROM OPENAI FOR One year after the e
# GOT EMBEDDING FROM OPENAI FOR The Losers are an el
# GOT EMBEDDING FROM OPENAI FOR Aspiring news produc
# GOT EMBEDDING FROM OPENAI FOR College student Max
# GOT EMBEDDING FROM OPENAI FOR In 2004 Houston, Jac
# GOT EMBEDDING FROM OPENAI FOR Ever since they arri
# GOT EMBEDDING FROM OPENAI FOR On April 8, 2000, Ma
# GOT EMBEDDING FROM OPENAI FOR Marmaduke, a teenage
# GOT EMBEDDING FROM OPENAI FOR Mexico: Machete Cort
# GOT EMBEDDING FROM OPENAI FOR In eastern Siberia's
# GOT EMBEDDING FROM OPENAI FOR The film follows Kev
# GOT EMBEDDING FROM OPENAI FOR Five years after the
# GOT EMBEDDING FROM OPENAI FOR Family man Abel Plen
# GOT EMBEDDING FROM OPENAI FOR Two police officers
# GOT EMBEDDING FROM OPENAI FOR Holly Berenson (Kath
# GOT EMBEDDING FROM OPENAI FOR Sophie (Amanda Seyfr
# GOT EMBEDDING FROM OPENAI FOR Tyler Doherty (Tanne
# GOT EMBEDDING FROM OPENAI FOR In March 1983, in Lo
# GOT EMBEDDING FROM OPENAI FOR The Archangel Michae
# GOT EMBEDDING FROM OPENAI FOR After being bullied,
# GOT EMBEDDING FROM OPENAI FOR In 2025, advancement
# GOT EMBEDDING FROM OPENAI FOR Soren, a 17 year old
# GOT EMBEDDING FROM OPENAI FOR When she was 14, Kar
# GOT EMBEDDING FROM OPENAI FOR In 1996, Jamie Randa
# GOT EMBEDDING FROM OPENAI FOR Royce awakens to fin
# GOT EMBEDDING FROM OPENAI FOR In New York City, Ze
# GOT EMBEDDING FROM OPENAI FOR Frank Moses, retired
# GOT EMBEDDING FROM OPENAI FOR On a farm during Wor
# GOT EMBEDDING FROM OPENAI FOR A housewife and moth
# GOT EMBEDDING FROM OPENAI FOR The adventurous and
# GOT EMBEDDING FROM OPENAI FOR Becca and Howie Corb
# GOT EMBEDDING FROM OPENAI FOR Dastan, a street urc
# GOT EMBEDDING FROM OPENAI FOR Small-town preacher'
# GOT EMBEDDING FROM OPENAI FOR Kate (Keener) and Al
# GOT EMBEDDING FROM OPENAI FOR Fisherman Matt Boyd
# GOT EMBEDDING FROM OPENAI FOR César Faz (Clifton C
# GOT EMBEDDING FROM OPENAI FOR Nate (Mickey Rourke)
# GOT EMBEDDING FROM OPENAI FOR August 2006, a "burg
# GOT EMBEDDING FROM OPENAI FOR Richard is a failed
# GOT EMBEDDING FROM OPENAI FOR Marcus Boyd (Lance G
# GOT EMBEDDING FROM OPENAI FOR Allen Gamble (Will F
# GOT EMBEDDING FROM OPENAI FOR Kris Fowles (Katie C
# GOT EMBEDDING FROM OPENAI FOR In 1976 former Black
# GOT EMBEDDING FROM OPENAI FOR Lara Brennan (Elizab
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR At New York City in
# GOT EMBEDDING FROM OPENAI FOR George Simmons (Adam
# GOT EMBEDDING FROM OPENAI FOR In 2034, computer pr
# GOT EMBEDDING FROM OPENAI FOR The film revolves ar
# GOT EMBEDDING FROM OPENAI FOR In the near future,
# GOT EMBEDDING FROM OPENAI FOR After a group of out
# GOT EMBEDDING FROM OPENAI FOR In 1969, Pasadena, C
# GOT EMBEDDING FROM OPENAI FOR Benjamin Purvis live
# GOT EMBEDDING FROM OPENAI FOR Connor Mead (Matthew
# GOT EMBEDDING FROM OPENAI FOR Ben Selleck's car de
# GOT EMBEDDING FROM OPENAI FOR While in a restauran
# GOT EMBEDDING FROM OPENAI FOR Troy Gable (Colin Ha
# GOT EMBEDDING FROM OPENAI FOR On June 13, 1980, a
# GOT EMBEDDING FROM OPENAI FOR Five years ago. Ray
# GOT EMBEDDING FROM OPENAI FOR Nick Brady and Shawn
# GOT EMBEDDING FROM OPENAI FOR College student Nick
# GOT EMBEDDING FROM OPENAI FOR Present day New York
# GOT EMBEDDING FROM OPENAI FOR Five years after the
# GOT EMBEDDING FROM OPENAI FOR While raiding Berk's
# GOT EMBEDDING FROM OPENAI FOR During the opening s
# GOT EMBEDDING FROM OPENAI FOR Joel Reynolds (Jason
# GOT EMBEDDING FROM OPENAI FOR Frank Goode, a recen
# GOT EMBEDDING FROM OPENAI FOR Max, a young America
# GOT EMBEDDING FROM OPENAI FOR Two thousand years a
# GOT EMBEDDING FROM OPENAI FOR In a flashback, Debo
# GOT EMBEDDING FROM OPENAI FOR Jake Kimble (the onl
# GOT EMBEDDING FROM OPENAI FOR The movie opens in 1
# GOT EMBEDDING FROM OPENAI FOR To celebrate his upc
# GOT EMBEDDING FROM OPENAI FOR The film's plot is l
# GOT EMBEDDING FROM OPENAI FOR A successful Manhatt
# GOT EMBEDDING FROM OPENAI FOR Louis Salinger, an I
# GOT EMBEDDING FROM OPENAI FOR In 1941, SS colonel
# GOT EMBEDDING FROM OPENAI FOR Mark Whitacre, a ris
# GOT EMBEDDING FROM OPENAI FOR Doctor Parnassus' th
# GOT EMBEDDING FROM OPENAI FOR Evan Danielson (Eddi
# GOT EMBEDDING FROM OPENAI FOR Ellie and Manny, the
# GOT EMBEDDING FROM OPENAI FOR Peter Klaven (Paul R
# GOT EMBEDDING FROM OPENAI FOR On graduation day at
# GOT EMBEDDING FROM OPENAI FOR In 2004, Sergeant Fi
# GOT EMBEDDING FROM OPENAI FOR Florist Genevieve Ge
# GOT EMBEDDING FROM OPENAI FOR Miley Stewart is str
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Two heterosexual mal
# GOT EMBEDDING FROM OPENAI FOR In Central City, Lou
# GOT EMBEDDING FROM OPENAI FOR Detective Aidan Bres
# GOT EMBEDDING FROM OPENAI FOR A group of people hu
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR 17-year-old Dane Tho
# GOT EMBEDDING FROM OPENAI FOR Nine people in Balti
# GOT EMBEDDING FROM OPENAI FOR In 1987, Sara Campbe
# GOT EMBEDDING FROM OPENAI FOR Lord Voldemort is ti
# GOT EMBEDDING FROM OPENAI FOR In 1982, an alien sh
# GOT EMBEDDING FROM OPENAI FOR In Germany, 1930, a
# GOT EMBEDDING FROM OPENAI FOR Suburban girl Megan
# GOT EMBEDDING FROM OPENAI FOR After immigrant Mire
# GOT EMBEDDING FROM OPENAI FOR In August 2005, Tere
# GOT EMBEDDING FROM OPENAI FOR Verona De Tessant (M
# GOT EMBEDDING FROM OPENAI FOR In 2154, humans have
# GOT EMBEDDING FROM OPENAI FOR Toby Tenma is a 13 y
# GOT EMBEDDING FROM OPENAI FOR Bobby Funke (Reece T
# GOT EMBEDDING FROM OPENAI FOR Ty Hackett (Columbus
# GOT EMBEDDING FROM OPENAI FOR After a car accident
# GOT EMBEDDING FROM OPENAI FOR Everyone wants to me
# GOT EMBEDDING FROM OPENAI FOR Under the watchful e
# GOT EMBEDDING FROM OPENAI FOR Set in the midst of
# GOT EMBEDDING FROM OPENAI FOR On July 2, 1937, Ame
# GOT EMBEDDING FROM OPENAI FOR During a benefit con
# GOT EMBEDDING FROM OPENAI FOR The film is presente
# GOT EMBEDDING FROM OPENAI FOR Mary Horowitz, a cro
# GOT EMBEDDING FROM OPENAI FOR A meteor shower rock
# GOT EMBEDDING FROM OPENAI FOR The story begins in
# GOT EMBEDDING FROM OPENAI FOR Eliot Deacon (Liam N
# GOT EMBEDDING FROM OPENAI FOR In 1987, James Brenn
# GOT EMBEDDING FROM OPENAI FOR Adam Raki (Dancy) is
# GOT EMBEDDING FROM OPENAI FOR In 2009, American ge
# GOT EMBEDDING FROM OPENAI FOR In 1989, 17-year-old
# GOT EMBEDDING FROM OPENAI FOR A sting operation to
# GOT EMBEDDING FROM OPENAI FOR Mona Gray (Jessica A
# GOT EMBEDDING FROM OPENAI FOR Will Burton (Gaelan
# GOT EMBEDDING FROM OPENAI FOR Mala (Evan Rachel Wo
# GOT EMBEDDING FROM OPENAI FOR Beginning in 1984 an
# GOT EMBEDDING FROM OPENAI FOR A deranged man calli
# GOT EMBEDDING FROM OPENAI FOR Otis "Bad" Blake (Je
# GOT EMBEDDING FROM OPENAI FOR Immediately after th
# GOT EMBEDDING FROM OPENAI FOR Dave, a dealer for G
# GOT EMBEDDING FROM OPENAI FOR Coraline Jones and h
# GOT EMBEDDING FROM OPENAI FOR Rebecca Bloomwood is
# GOT EMBEDDING FROM OPENAI FOR A man named Larry an
# GOT EMBEDDING FROM OPENAI FOR Paul Giamatti is an
# GOT EMBEDDING FROM OPENAI FOR Flint Lockwood is a
# GOT EMBEDDING FROM OPENAI FOR 16-year-old Darren S
# GOT EMBEDDING FROM OPENAI FOR In 1843, on Christma
# GOT EMBEDDING FROM OPENAI FOR An infectious virus
# GOT EMBEDDING FROM OPENAI FOR Shreveport, Louisian
# GOT EMBEDDING FROM OPENAI FOR The story centers ar
# GOT EMBEDDING FROM OPENAI FOR Gay Austrian fashion
# GOT EMBEDDING FROM OPENAI FOR The Brothers Bloom,
# GOT EMBEDDING FROM OPENAI FOR Sam Cahill (Tobey Ma
# GOT EMBEDDING FROM OPENAI FOR Emma Allen and Olivi
# GOT EMBEDDING FROM OPENAI FOR In December 1976, fi
# GOT EMBEDDING FROM OPENAI FOR After the McManus br
# GOT EMBEDDING FROM OPENAI FOR The film is describe
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Paul Aufiero (Patton
# GOT EMBEDDING FROM OPENAI FOR On 11 February 1990,
# GOT EMBEDDING FROM OPENAI FOR Utilizing an alterna
# GOT EMBEDDING FROM OPENAI FOR The film is set in a
# GOT EMBEDDING FROM OPENAI FOR When the master thie
# GOT EMBEDDING FROM OPENAI FOR Chun-Li moves from S
# GOT EMBEDDING FROM OPENAI FOR The film opens as Gr
# GOT EMBEDDING FROM OPENAI FOR One night, a thief f
# GOT EMBEDDING FROM OPENAI FOR In the 23rd century,
# GOT EMBEDDING FROM OPENAI FOR Narcissistic gigolo
# GOT EMBEDDING FROM OPENAI FOR After finding out th
# GOT EMBEDDING FROM OPENAI FOR In 2005, Steve Lopez
# GOT EMBEDDING FROM OPENAI FOR "Slammin" Cleon Salm
# GOT EMBEDDING FROM OPENAI FOR On November 30, 1962
# GOT EMBEDDING FROM OPENAI FOR Toby "Toe" Thompson
# GOT EMBEDDING FROM OPENAI FOR In Hollywood, Psychi
# GOT EMBEDDING FROM OPENAI FOR In 1890, private det
# GOT EMBEDDING FROM OPENAI FOR In a prologue, a Jew
# GOT EMBEDDING FROM OPENAI FOR Two predatory lender
# GOT EMBEDDING FROM OPENAI FOR A man and his young
# GOT EMBEDDING FROM OPENAI FOR An alien spacecraft
# GOT EMBEDDING FROM OPENAI FOR In 1945, the United
# GOT EMBEDDING FROM OPENAI FOR After killing Charle
# GOT EMBEDDING FROM OPENAI FOR Margaret Tate (Sandr
# GOT EMBEDDING FROM OPENAI FOR The film chronicles
# GOT EMBEDDING FROM OPENAI FOR In 1912 New Orleans,
# GOT EMBEDDING FROM OPENAI FOR In 1987, 16-year-old
# GOT EMBEDDING FROM OPENAI FOR Ryden Malby graduate
# GOT EMBEDDING FROM OPENAI FOR In the future, wides
# GOT EMBEDDING FROM OPENAI FOR A man calling himsel
# GOT EMBEDDING FROM OPENAI FOR Set in 1969, the fil
# GOT EMBEDDING FROM OPENAI FOR Brooklyn slacker Max
# GOT EMBEDDING FROM OPENAI FOR The film documents t
# GOT EMBEDDING FROM OPENAI FOR Two months have pass
# GOT EMBEDDING FROM OPENAI FOR Princess Victoria of
# GOT EMBEDDING FROM OPENAI FOR Zed (Jack Black) is
# GOT EMBEDDING FROM OPENAI FOR In 1845, James Howle
# GOT EMBEDDING FROM OPENAI FOR Bliss Cavendar (Elle
# GOT EMBEDDING FROM OPENAI FOR In 1957 a Russian ca
# GOT EMBEDDING FROM OPENAI FOR Max, a lonely eight-
# GOT EMBEDDING FROM OPENAI FOR Boris Yelnikoff (Lar
# GOT EMBEDDING FROM OPENAI FOR Upon arriving in Con
# GOT EMBEDDING FROM OPENAI FOR Ryan Bingham works f
# GOT EMBEDDING FROM OPENAI FOR In the late 2010s, a
# GOT EMBEDDING FROM OPENAI FOR In 1940, nine-year-o
# GOT EMBEDDING FROM OPENAI FOR Anna (Emily Browning
# GOT EMBEDDING FROM OPENAI FOR The film tells the s
# GOT EMBEDDING FROM OPENAI FOR Casey Beldon has nig
# GOT EMBEDDING FROM OPENAI FOR Abby Richter (Kather
# GOT EMBEDDING FROM OPENAI FOR It is Halloween nigh
# GOT EMBEDDING FROM OPENAI FOR In 17,000 B.C., the
# GOT EMBEDDING FROM OPENAI FOR In the early 1970s,
# GOT EMBEDDING FROM OPENAI FOR In 2003, Dr. Serena
# GOT EMBEDDING FROM OPENAI FOR Two brothers, Ellis
# GOT EMBEDDING FROM OPENAI FOR On Planet 51, green
# GOT EMBEDDING FROM OPENAI FOR Lance Clayton (Robin
# GOT EMBEDDING FROM OPENAI FOR A 9-year-old girl, P
# GOT EMBEDDING FROM OPENAI FOR The plot revolves ar
# GOT EMBEDDING FROM OPENAI FOR In New York City in
# GOT EMBEDDING FROM OPENAI FOR Mike Flux (Steve Zah
# GOT EMBEDDING FROM OPENAI FOR Roger (Christopher W
# GOT EMBEDDING FROM OPENAI FOR After a high-speed f
# GOT EMBEDDING FROM OPENAI FOR Set in 1979 Syosset,
# GOT EMBEDDING FROM OPENAI FOR In 1973, 14-year-old
# GOT EMBEDDING FROM OPENAI FOR Jessica Donovan (Amy
# GOT EMBEDDING FROM OPENAI FOR Burke Ryan (Aaron Ec
# GOT EMBEDDING FROM OPENAI FOR In an airport, Lone
# GOT EMBEDDING FROM OPENAI FOR The film is set on C
# GOT EMBEDDING FROM OPENAI FOR In a home invasion,
# GOT EMBEDDING FROM OPENAI FOR Will Montgomery (Ben
# GOT EMBEDDING FROM OPENAI FOR Emma (Monica Potter)
# GOT EMBEDDING FROM OPENAI FOR Pompous paleontologi
# GOT EMBEDDING FROM OPENAI FOR A young woman with a
# GOT EMBEDDING FROM OPENAI FOR Thea Clayhill is abo
# GOT EMBEDDING FROM OPENAI FOR In 1959, Lucinda Emb
# GOT EMBEDDING FROM OPENAI FOR In 2002, Julie Powel
# GOT EMBEDDING FROM OPENAI FOR Anita "Needy" Lesnic
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Jane (Meryl Streep),
# GOT EMBEDDING FROM OPENAI FOR A young mild-mannere
# GOT EMBEDDING FROM OPENAI FOR In a short prelude,
# GOT EMBEDDING FROM OPENAI FOR The 3D Concert Exper
# GOT EMBEDDING FROM OPENAI FOR The movie begins wit
# GOT EMBEDDING FROM OPENAI FOR The Ozunu Clan, led
# GOT EMBEDDING FROM OPENAI FOR In the far reaches o
# GOT EMBEDDING FROM OPENAI FOR The film follows Cha
# GOT EMBEDDING FROM OPENAI FOR Kate and John Colema
# GOT EMBEDDING FROM OPENAI FOR At 30 years old, Opi
# GOT EMBEDDING FROM OPENAI FOR Dan Rayburn (Robin W
# GOT EMBEDDING FROM OPENAI FOR Derek Charles (Idris
# GOT EMBEDDING FROM OPENAI FOR An anonymous flasher
# GOT EMBEDDING FROM OPENAI FOR The film opens at a
# GOT EMBEDDING FROM OPENAI FOR Jack Bishop (Simon B
# GOT EMBEDDING FROM OPENAI FOR Dave (Morris Chestnu
# GOT EMBEDDING FROM OPENAI FOR In 2174, the human p
# GOT EMBEDDING FROM OPENAI FOR Guido Contini (Danie
# GOT EMBEDDING FROM OPENAI FOR Kate Fitzgerald (Sof
# GOT EMBEDDING FROM OPENAI FOR In New York's West V
# GOT EMBEDDING FROM OPENAI FOR On St. Valentine's D
# GOT EMBEDDING FROM OPENAI FOR Larry Daley, former
# GOT EMBEDDING FROM OPENAI FOR Georgia (Nia Vardalo
# GOT EMBEDDING FROM OPENAI FOR Paul Blart lives in
# GOT EMBEDDING FROM OPENAI FOR On her eighteenth bi
# GOT EMBEDDING FROM OPENAI FOR Leo works for Next D
# GOT EMBEDDING FROM OPENAI FOR In New York City in
# GOT EMBEDDING FROM OPENAI FOR A high-powered consu
# GOT EMBEDDING FROM OPENAI FOR After returning home
# GOT EMBEDDING FROM OPENAI FOR Harold Reynolds (Spe
# GOT EMBEDDING FROM OPENAI FOR In New York City's C
# GOT EMBEDDING FROM OPENAI FOR John Hancock is an a
# GOT EMBEDDING FROM OPENAI FOR Dana Marschz is a re
# GOT EMBEDDING FROM OPENAI FOR Walt Kowalski (Clint
# GOT EMBEDDING FROM OPENAI FOR The film begins as m
# GOT EMBEDDING FROM OPENAI FOR Maxwell "Max" Smart,
# GOT EMBEDDING FROM OPENAI FOR George and Ann Farbe
# GOT EMBEDDING FROM OPENAI FOR The film is set shor
# GOT EMBEDDING FROM OPENAI FOR Family man Wade Port
# GOT EMBEDDING FROM OPENAI FOR The story moves back
# GOT EMBEDDING FROM OPENAI FOR After the Watergate
# GOT EMBEDDING FROM OPENAI FOR Brad (Vince Vaughn)
# GOT EMBEDDING FROM OPENAI FOR Composer Peter Brett
# GOT EMBEDDING FROM OPENAI FOR South Boston teenage
# GOT EMBEDDING FROM OPENAI FOR "Finn" Finnegan is a
# GOT EMBEDDING FROM OPENAI FOR On his wedding night
# GOT EMBEDDING FROM OPENAI FOR The film is set in B
# GOT EMBEDDING FROM OPENAI FOR Married couple Caleb
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Rick Penning (Sean F
# GOT EMBEDDING FROM OPENAI FOR In 1957, Indiana Jon
# GOT EMBEDDING FROM OPENAI FOR During Christmas 195
# GOT EMBEDDING FROM OPENAI FOR Having been diagnose
# GOT EMBEDDING FROM OPENAI FOR Minden, Illinois, is
# GOT EMBEDDING FROM OPENAI FOR Sydney Wells is a su
# GOT EMBEDDING FROM OPENAI FOR Guru Pitka is the #2
# GOT EMBEDDING FROM OPENAI FOR In 1925 Jimmy "Dodge
# GOT EMBEDDING FROM OPENAI FOR Divorced American Ha
# GOT EMBEDDING FROM OPENAI FOR An interracial newly
# GOT EMBEDDING FROM OPENAI FOR In the Valley of Pea
# GOT EMBEDDING FROM OPENAI FOR In June 1934, Kit Ki
# GOT EMBEDDING FROM OPENAI FOR In Ann Arbor, Michig
# GOT EMBEDDING FROM OPENAI FOR Max Anderson (Jean-M
# GOT EMBEDDING FROM OPENAI FOR Genius, billionaire,
# GOT EMBEDDING FROM OPENAI FOR At Culver University
# GOT EMBEDDING FROM OPENAI FOR Carrying out orders,
# GOT EMBEDDING FROM OPENAI FOR The Kingdom of Malar
# GOT EMBEDDING FROM OPENAI FOR Shelley Darlington (
# GOT EMBEDDING FROM OPENAI FOR Nate Cooper is unabl
# GOT EMBEDDING FROM OPENAI FOR A dust speck is disl
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Liam Case (Cuba Good
# ...
# GOT EMBEDDING FROM OPENAI FOR The Windsor Protocol
# GOT EMBEDDING FROM OPENAI FOR Phillip is a naive n
# GOT EMBEDDING FROM OPENAI FOR The two Wheaton sist
# GOT EMBEDDING FROM OPENAI FOR Intelligent aliens w
# GOT EMBEDDING FROM OPENAI FOR Dr. David Krane (Ray
# GOT EMBEDDING FROM OPENAI FOR Art Dodge (Antonio B
# GOT EMBEDDING FROM OPENAI FOR One stormy night in
# GOT EMBEDDING FROM OPENAI FOR Phillip and Dieter n
# GOT EMBEDDING FROM OPENAI FOR Roy "Tin Cup" McAvoy
# GOT EMBEDDING FROM OPENAI FOR Titanic follows thre
# GOT EMBEDDING FROM OPENAI FOR Set in 1979, the fil
# GOT EMBEDDING FROM OPENAI FOR David Lewis (Peter G
# GOT EMBEDDING FROM OPENAI FOR Mark Thackeray (Sidn
# GOT EMBEDDING FROM OPENAI FOR This film follows th
# GOT EMBEDDING FROM OPENAI FOR Jake Thorne (Bruce C
# GOT EMBEDDING FROM OPENAI FOR Jennifer Stanton (Ha
# GOT EMBEDDING FROM OPENAI FOR Tommy Basilio is an
# GOT EMBEDDING FROM OPENAI FOR A man on an oil fiel
# GOT EMBEDDING FROM OPENAI FOR Annie and Matthew, a
# GOT EMBEDDING FROM OPENAI FOR A wealthy man by the
# GOT EMBEDDING FROM OPENAI FOR Set in modern-day Ma
# GOT EMBEDDING FROM OPENAI FOR Abby Barnes (Garofal
# GOT EMBEDDING FROM OPENAI FOR A group of rogue U.S
# GOT EMBEDDING FROM OPENAI FOR Amelia (Keener) and
# GOT EMBEDDING FROM OPENAI FOR Josie Potenza is the
# GOT EMBEDDING FROM OPENAI FOR Set in 1960, the sto
# GOT EMBEDDING FROM OPENAI FOR Faith Ferguson (Mimi
# GOT EMBEDDING FROM OPENAI FOR At Loch Ness, Scotla
# GOT EMBEDDING FROM OPENAI FOR Sheriff Sam Deeds is
# GOT EMBEDDING FROM OPENAI FOR Samantha Caine (Geen
# GOT EMBEDDING FROM OPENAI FOR Love Is All There Is
# GOT EMBEDDING FROM OPENAI FOR Michael Walsh, a hus
# GOT EMBEDDING FROM OPENAI FOR In Kentucky, a famil
# GOT EMBEDDING FROM OPENAI FOR A man who had a stro
# GOT EMBEDDING FROM OPENAI FOR Mary Reilly comes to
# GOT EMBEDDING FROM OPENAI FOR Matilda Wormwood is
# GOT EMBEDDING FROM OPENAI FOR Alain Moreau (Jean-C
# GOT EMBEDDING FROM OPENAI FOR The year is 2015 and
# GOT EMBEDDING FROM OPENAI FOR Although the opening
# GOT EMBEDDING FROM OPENAI FOR David discovers ever
# GOT EMBEDDING FROM OPENAI FOR The founder of virtu
# GOT EMBEDDING FROM OPENAI FOR In 1922, Joe O'Reill
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR In 1991, the remains
# GOT EMBEDDING FROM OPENAI FOR Howard Langston is a
# GOT EMBEDDING FROM OPENAI FOR Penniless and straig
# GOT EMBEDDING FROM OPENAI FOR It's Christmas Eve a
# GOT EMBEDDING FROM OPENAI FOR Annie Laird (Demi Mo
# GOT EMBEDDING FROM OPENAI FOR Set in 16th century
# GOT EMBEDDING FROM OPENAI FOR The book details Ame
# GOT EMBEDDING FROM OPENAI FOR Behind-the-scenes ne
# GOT EMBEDDING FROM OPENAI FOR Flashy young bowler
# GOT EMBEDDING FROM OPENAI FOR Littlefoot notices a
# GOT EMBEDDING FROM OPENAI FOR The film opens at a
# GOT EMBEDDING FROM OPENAI FOR Cindy Liggett (Sharo
# GOT EMBEDDING FROM OPENAI FOR Frankie (Dennis Hopp
# GOT EMBEDDING FROM OPENAI FOR In 1932 Prohibition-
# GOT EMBEDDING FROM OPENAI FOR The National Mirror
# GOT EMBEDDING FROM OPENAI FOR A kidnapping goes do
# GOT EMBEDDING FROM OPENAI FOR Rose Morgan (Streisa
# GOT EMBEDDING FROM OPENAI FOR The film revolves ar
# GOT EMBEDDING FROM OPENAI FOR In 1952, 10-year-old
# GOT EMBEDDING FROM OPENAI FOR In the early 16th ce
# GOT EMBEDDING FROM OPENAI FOR During a glorious So
# GOT EMBEDDING FROM OPENAI FOR George Malley is a k
# GOT EMBEDDING FROM OPENAI FOR Despite the evidence
# GOT EMBEDDING FROM OPENAI FOR Lily is a sheltered
# GOT EMBEDDING FROM OPENAI FOR Isabel Archer, origi
# GOT EMBEDDING FROM OPENAI FOR Tom Thompson (David
# GOT EMBEDDING FROM OPENAI FOR A voiceover by the c
# GOT EMBEDDING FROM OPENAI FOR Martin Vail (Richard
# GOT EMBEDDING FROM OPENAI FOR Late night in an emp
# GOT EMBEDDING FROM OPENAI FOR A new science teache
# GOT EMBEDDING FROM OPENAI FOR Years after the even
# GOT EMBEDDING FROM OPENAI FOR While multi-milliona
# GOT EMBEDDING FROM OPENAI FOR The story begins in
# GOT EMBEDDING FROM OPENAI FOR Sexually abused by h
# GOT EMBEDDING FROM OPENAI FOR Julie Longwell, the
# GOT EMBEDDING FROM OPENAI FOR In the early 1950s,
# GOT EMBEDDING FROM OPENAI FOR The movie opens to a
# GOT EMBEDDING FROM OPENAI FOR John Henderson (Albe
# GOT EMBEDDING FROM OPENAI FOR A former divorcé lea
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR Al McCord is hanging
# GOT EMBEDDING FROM OPENAI FOR Establishing shot of
# GOT EMBEDDING FROM OPENAI FOR Confined in an Israe
# GOT EMBEDDING FROM OPENAI FOR Doug Kinney (Michael
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Melanie Parker (Mich
# GOT EMBEDDING FROM OPENAI FOR At Wellman College,
# GOT EMBEDDING FROM OPENAI FOR Moll's mother is a c
# GOT EMBEDDING FROM OPENAI FOR Republican Senator R
# GOT EMBEDDING FROM OPENAI FOR Jim Hawkins is a you
# GOT EMBEDDING FROM OPENAI FOR Chili Palmer, a loan
# GOT EMBEDDING FROM OPENAI FOR Fifteen-year-old Ang
# GOT EMBEDDING FROM OPENAI FOR Tommy Fawkes is the
# GOT EMBEDDING FROM OPENAI FOR Claudia is the middl
# GOT EMBEDDING FROM OPENAI FOR John "J. J." Johnson
# GOT EMBEDDING FROM OPENAI FOR A fastidious and who
# GOT EMBEDDING FROM OPENAI FOR It's been two years
# GOT EMBEDDING FROM OPENAI FOR The film is set on N
# GOT EMBEDDING FROM OPENAI FOR At a restaurant in N
# GOT EMBEDDING FROM OPENAI FOR Fluke is a mutt pupp
# GOT EMBEDDING FROM OPENAI FOR In New York, Bill (B
# GOT EMBEDDING FROM OPENAI FOR The film's opening t
# GOT EMBEDDING FROM OPENAI FOR The film begins five
# GOT EMBEDDING FROM OPENAI FOR Craig Jones, a young
# GOT EMBEDDING FROM OPENAI FOR The title character
# GOT EMBEDDING FROM OPENAI FOR Three friends decide
# GOT EMBEDDING FROM OPENAI FOR Kathryn "Kate" McQue
# GOT EMBEDDING FROM OPENAI FOR An enigmatic, homele
# GOT EMBEDDING FROM OPENAI FOR Teenage computer whi
# GOT EMBEDDING FROM OPENAI FOR Empire Records is an
# GOT EMBEDDING FROM OPENAI FOR The pair of Bobby Ke
# GOT EMBEDDING FROM OPENAI FOR Solicitor Thomas Ren
# GOT EMBEDDING FROM OPENAI FOR Richard Jacks (Tim D
# GOT EMBEDDING FROM OPENAI FOR Teenage lovers Jorda
# GOT EMBEDDING FROM OPENAI FOR Psychiatrist Jack Mi
# GOT EMBEDDING FROM OPENAI FOR In 1995, Dolores Cla
# GOT EMBEDDING FROM OPENAI FOR It is the last day o
# GOT EMBEDDING FROM OPENAI FOR In New York City, th
# GOT EMBEDDING FROM OPENAI FOR In the summer of 194
# GOT EMBEDDING FROM OPENAI FOR In June 1980, Beth E
# GOT EMBEDDING FROM OPENAI FOR Claudia Larson, a si
# GOT EMBEDDING FROM OPENAI FOR A piglet named Gordy
# GOT EMBEDDING FROM OPENAI FOR Terri Venessi (Mary
# GOT EMBEDDING FROM OPENAI FOR The film opens in a
# GOT EMBEDDING FROM OPENAI FOR A woman, having rece
# GOT EMBEDDING FROM OPENAI FOR The story takes plac
# GOT EMBEDDING FROM OPENAI FOR Set in the period 17
# GOT EMBEDDING FROM OPENAI FOR San Francisco Assist
# GOT EMBEDDING FROM OPENAI FOR The Kelly family liv
# GOT EMBEDDING FROM OPENAI FOR Two unrelated young
# GOT EMBEDDING FROM OPENAI FOR On his ninth birthda
# GOT EMBEDDING FROM OPENAI FOR It is spring. Randy
# GOT EMBEDDING FROM OPENAI FOR In the midst of an u
# GOT EMBEDDING FROM OPENAI FOR A crafty nightclub o
# GOT EMBEDDING FROM OPENAI FOR In a black-and-white
# GOT EMBEDDING FROM OPENAI FOR Paul Racine, a compu
# GOT EMBEDDING FROM OPENAI FOR Kevin Franklin (Sinb
# GOT EMBEDDING FROM OPENAI FOR Set in a remote dese
# GOT EMBEDDING FROM OPENAI FOR At fictitious Columb
# GOT EMBEDDING FROM OPENAI FOR After killing two wo
# GOT EMBEDDING FROM OPENAI FOR The Munster family i
# GOT EMBEDDING FROM OPENAI FOR As school ends for t
# GOT EMBEDDING FROM OPENAI FOR The film begins at P
# GOT EMBEDDING FROM OPENAI FOR Neil McCauley, a car
# GOT EMBEDDING FROM OPENAI FOR In 1928 England, Dav
# GOT EMBEDDING FROM OPENAI FOR Harrison Bergeron li
# GOT EMBEDDING FROM OPENAI FOR On October 31, 1989,
# GOT EMBEDDING FROM OPENAI FOR In 1988, 11-year-old
# GOT EMBEDDING FROM OPENAI FOR When the Blockheads'
# GOT EMBEDDING FROM OPENAI FOR The feud between Max
# GOT EMBEDDING FROM OPENAI FOR At the Tarasco bar i
# GOT EMBEDDING FROM OPENAI FOR Darcy Walker (Joan S
# GOT EMBEDDING FROM OPENAI FOR In the spring of 196
# GOT EMBEDDING FROM OPENAI FOR Babe, an orphaned pi
# GOT EMBEDDING FROM OPENAI FOR Air Force courier Ni
# GOT EMBEDDING FROM OPENAI FOR Billy Madison is the
# GOT EMBEDDING FROM OPENAI FOR Teacher Anna Montgom
# GOT EMBEDDING FROM OPENAI FOR Andy Bowman persuade
# GOT EMBEDDING FROM OPENAI FOR The film starts on J
# GOT EMBEDDING FROM OPENAI FOR Baywatch lifeguards
# GOT EMBEDDING FROM OPENAI FOR In Gotham City, the
# GOT EMBEDDING FROM OPENAI FOR The film is an adapt
# GOT EMBEDDING FROM OPENAI FOR In New York City, an
# GOT EMBEDDING FROM OPENAI FOR Former CIA agent Nel
# GOT EMBEDDING FROM OPENAI FOR Miami detectives Mar
# GOT EMBEDDING FROM OPENAI FOR Kristy Thomas, presi
# GOT EMBEDDING FROM OPENAI FOR The three finalists
# GOT EMBEDDING FROM OPENAI FOR Matthew Poncelet has
# GOT EMBEDDING FROM OPENAI FOR Robert Rath (Sylvest
# GOT EMBEDDING FROM OPENAI FOR In July 1969, astron
# GOT EMBEDDING FROM OPENAI FOR Angus Bethune (Talbe
# GOT EMBEDDING FROM OPENAI FOR William Adamson (Mar
# GOT EMBEDDING FROM OPENAI FOR Angela is a 10-year-
# GOT EMBEDDING FROM OPENAI FOR Popular Democratic P
# GOT EMBEDDING FROM OPENAI FOR Ryan Tyler's father
# GOT EMBEDDING FROM OPENAI FOR Amanda, an employee
# GOT EMBEDDING FROM OPENAI FOR Kathleen Conklin (Ta
# GOT EMBEDDING FROM OPENAI FOR In the Himalayas, af
# GOT EMBEDDING FROM OPENAI FOR Christopher Reeve st
# GOT EMBEDDING FROM OPENAI FOR Rocky (Michael Trean
# GOT EMBEDDING FROM OPENAI FOR Joseph, a Hebrew, is
# GOT EMBEDDING FROM OPENAI FOR The film once again
# GOT EMBEDDING FROM OPENAI FOR Rick Heller is a juv
# GOT EMBEDDING FROM OPENAI FOR Three unique women e
# GOT EMBEDDING FROM OPENAI FOR Larry Dittmeyer, an
# GOT EMBEDDING FROM OPENAI FOR William Blake (Johnn
# GOT EMBEDDING FROM OPENAI FOR LouAnne Johnson (Mic
# GOT EMBEDDING FROM OPENAI FOR Crime boss Jesse Sta
# GOT EMBEDDING FROM OPENAI FOR In 1668 Jamaica, Mor
# GOT EMBEDDING FROM OPENAI FOR Set in a small town
# GOT EMBEDDING FROM OPENAI FOR Set in South Africa
# GOT EMBEDDING FROM OPENAI FOR Freddy Gale (Nichols
# GOT EMBEDDING FROM OPENAI FOR In post-Soviet Russi
# GOT EMBEDDING FROM OPENAI FOR After giving a guest
# GOT EMBEDDING FROM OPENAI FOR While testing a comm
# GOT EMBEDDING FROM OPENAI FOR Cosmo Reif, an affec
# GOT EMBEDDING FROM OPENAI FOR Cheryl "Cher" Horowi
# GOT EMBEDDING FROM OPENAI FOR In a Brooklyn, New Y
# GOT EMBEDDING FROM OPENAI FOR A body is discovered
# GOT EMBEDDING FROM OPENAI FOR Eli and Joshua are b
# GOT EMBEDDING FROM OPENAI FOR A young German Princ
# GOT EMBEDDING FROM OPENAI FOR After inheriting a 1
# GOT EMBEDDING FROM OPENAI FOR In the town of Frien
# GOT EMBEDDING FROM OPENAI FOR In 1973, sports hand
# GOT EMBEDDING FROM OPENAI FOR At the Yucca Mountai
# GOT EMBEDDING FROM OPENAI FOR Coleman Tarrant, the
# GOT EMBEDDING FROM OPENAI FOR Thousands of former
# GOT EMBEDDING FROM OPENAI FOR This is a story abou
# GOT EMBEDDING FROM OPENAI FOR Deliveryman "Mad" Ma
# GOT EMBEDDING FROM OPENAI FOR The film begins with
# GOT EMBEDDING FROM OPENAI FOR In the present, adul
# GOT EMBEDDING FROM OPENAI FOR In 1280, King Edward
# GOT EMBEDDING FROM OPENAI FOR In 2021, Johnny is a
# GOT EMBEDDING FROM OPENAI FOR Nina, an art dealer,
# GOT EMBEDDING FROM OPENAI FOR By the 2080s, much o
# GOT EMBEDDING FROM OPENAI FOR Nomi Malone is a you
# GOT EMBEDDING FROM OPENAI FOR In 2022, a comet str
# GOT EMBEDDING FROM OPENAI FOR Amy Winslow (Alyssa
# GOT EMBEDDING FROM OPENAI FOR Darren McCord (Jean-
# GOT EMBEDDING FROM OPENAI FOR Stuart Smalley (Al F
# GOT EMBEDDING FROM OPENAI FOR In the last two days
# GOT EMBEDDING FROM OPENAI FOR Matty Dean, a young
# GOT EMBEDDING FROM OPENAI FOR The setting is early
# GOT EMBEDDING FROM OPENAI FOR During the SETI prog
# GOT EMBEDDING FROM OPENAI FOR The film shows a sce
# GOT EMBEDDING FROM OPENAI FOR The film follows the
# GOT EMBEDDING FROM OPENAI FOR Seventeen years afte
# GOT EMBEDDING FROM OPENAI FOR Ernest takes a job w
# GOT EMBEDDING FROM OPENAI FOR Billy, a young skinh
# GOT EMBEDDING FROM OPENAI FOR Charlie Thorpe (Bill
# GOT EMBEDDING FROM OPENAI FOR Junior Healy (Justin
# GOT EMBEDDING FROM OPENAI FOR Soon-to-retire detec
# GOT EMBEDDING FROM OPENAI FOR On his deathbed, Mr.
# GOT EMBEDDING FROM OPENAI FOR In the year 2078, th
# GOT EMBEDDING FROM OPENAI FOR It is 1667 in the Ma
# GOT EMBEDDING FROM OPENAI FOR Japanese theaters sh
# GOT EMBEDDING FROM OPENAI FOR Set in an affluent n
# GOT EMBEDDING FROM OPENAI FOR Sabrina Fairchild is
# GOT EMBEDDING FROM OPENAI FOR Minnie visits Mickey
# GOT EMBEDDING FROM OPENAI FOR In 1963 Pittsburgh,
# GOT EMBEDDING FROM OPENAI FOR In Scotland, 1713, R
# GOT EMBEDDING FROM OPENAI FOR A young doctor, Robe
# GOT EMBEDDING FROM OPENAI FOR Relentlessly cheerfu
# GOT EMBEDDING FROM OPENAI FOR An unnamed gunslinge
# GOT EMBEDDING FROM OPENAI FOR In an alternate futu
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Jimmy "The Saint" To
# GOT EMBEDDING FROM OPENAI FOR In the present, a fa
# GOT EMBEDDING FROM OPENAI FOR In 1869, near Brantf
# GOT EMBEDDING FROM OPENAI FOR It is based on the t
# GOT EMBEDDING FROM OPENAI FOR In 1920s South Ameri
# GOT EMBEDDING FROM OPENAI FOR A well-known lawman
# GOT EMBEDDING FROM OPENAI FOR The movie begins wit
# GOT EMBEDDING FROM OPENAI FOR Lucy Eleanor Moderat
# GOT EMBEDDING FROM OPENAI FOR Eleven-and-a-half-ye
# GOT EMBEDDING FROM OPENAI FOR Long after the melti
# GOT EMBEDDING FROM OPENAI FOR In 1972 North Vietna
# GOT EMBEDDING FROM OPENAI FOR In 1945, after World
# GOT EMBEDDING FROM OPENAI FOR "Friends are the Peo
# GOT EMBEDDING FROM OPENAI FOR In Los Angeles, Lt.
# GOT EMBEDDING FROM OPENAI FOR All of the people, a
# GOT EMBEDDING FROM OPENAI FOR An abandoned ship cr
# GOT EMBEDDING FROM OPENAI FOR The film opens with
# GOT EMBEDDING FROM OPENAI FOR Michael Chambers ret
# GOT EMBEDDING FROM OPENAI FOR Casey Ryback retires
# GOT EMBEDDING FROM OPENAI FOR It is a hot summer d
# GOT EMBEDDING FROM OPENAI FOR A deadly virus relea
# GOT EMBEDDING FROM OPENAI FOR In a world where toy
# GOT EMBEDDING FROM OPENAI FOR The film opens as tw
# GOT EMBEDDING FROM OPENAI FOR After seven years at
# GOT EMBEDDING FROM OPENAI FOR The movie opens with
# GOT EMBEDDING FROM OPENAI FOR Anna Nicole Smith pl
# GOT EMBEDDING FROM OPENAI FOR After tying for the
# GOT EMBEDDING FROM OPENAI FOR Suzanne Stone dreams
# GOT EMBEDDING FROM OPENAI FOR In California, John
# GOT EMBEDDING FROM OPENAI FOR Thomas Dagget, a Cat
# GOT EMBEDDING FROM OPENAI FOR Bruno Buckingham is
# GOT EMBEDDING FROM OPENAI FOR Stan Dryer, an unsuc
# GOT EMBEDDING FROM OPENAI FOR In Seattle, straight
# GOT EMBEDDING FROM OPENAI FOR Rebecca Lott is a th
# GOT EMBEDDING FROM OPENAI FOR On Christmas, we mee
# GOT EMBEDDING FROM OPENAI FOR The Power Rangers pa
# GOT EMBEDDING FROM OPENAI FOR The film opens on an
# GOT EMBEDDING FROM OPENAI FOR The story is set in
# GOT EMBEDDING FROM OPENAI FOR Gwyn Marcus (Sarah J
# GOT EMBEDDING FROM OPENAI FOR Set in the 1940s in
# GOT EMBEDDING FROM OPENAI FOR A police detective i
# GOT EMBEDDING FROM OPENAI FOR Six-year-old Ben Arc
# GOT EMBEDDING FROM OPENAI FOR College student T.S.
# GOT EMBEDDING FROM OPENAI FOR U.S. Marine Corps Ma
# GOT EMBEDDING FROM OPENAI FOR Jack Carlisle is a d
# GOT EMBEDDING FROM OPENAI FOR Ashley Black is depr
# GOT EMBEDDING FROM OPENAI FOR While craving her ne
# GOT EMBEDDING FROM OPENAI FOR Mortal Kombat is a f
# GOT EMBEDDING FROM OPENAI FOR In the Mojave Desert
# GOT EMBEDDING FROM OPENAI FOR The film is divided
# GOT EMBEDDING FROM OPENAI FOR In the year 1914, Sa
# GOT EMBEDDING FROM OPENAI FOR A college freshman R
# GOT EMBEDDING FROM OPENAI FOR Ben Sanderson is a H
# GOT EMBEDDING FROM OPENAI FOR Distraught but skill
# GOT EMBEDDING FROM OPENAI FOR One day, a shower of
# GOT EMBEDDING FROM OPENAI FOR Jimmy Kilmartin is a
# GOT EMBEDDING FROM OPENAI FOR Telly and a 12-year-
# GOT EMBEDDING FROM OPENAI FOR Allan Breck Stewart
# GOT EMBEDDING FROM OPENAI FOR Paul Armstrong (Sean
# GOT EMBEDDING FROM OPENAI FOR Jeremy "Powder" Reed
# GOT EMBEDDING FROM OPENAI FOR Tommy Collins is an
# GOT EMBEDDING FROM OPENAI FOR Calvin Fuller is a n
# GOT EMBEDDING FROM OPENAI FOR In Portland, Oregon
# GOT EMBEDDING FROM OPENAI FOR During the Vietnam W

# %%
len(plot_embeddings)
# Out:
# 5000

# %% [markdown]
# ## Plot The Embeddings Using Atlas

# %%
data = movies[["Title", "Genre"]].to_dict("records")

# %%
from nomic import atlas

# %%
project = atlas.map_embeddings(
    embeddings=np.array(plot_embeddings),
    data=data
)
# Out:
# 2023-07-03 11:34:47.585 | INFO     | nomic.project:_create_project:749 - Creating project `quixotic-spleen` in organization `eduardosthory69`
# 2023-07-03 11:34:49.614 | INFO     | nomic.atlas:map_embeddings:107 - Uploading embeddings to Atlas.
# 4it [00:05,  1.34s/it]
# 2023-07-03 11:34:56.280 | INFO     | nomic.project:_add_data:1371 - Upload succeeded.
# 2023-07-03 11:34:56.282 | INFO     | nomic.atlas:map_embeddings:126 - Embedding upload succeeded.
# 2023-07-03 11:34:57.931 | INFO     | nomic.project:create_index:1081 - Created map `quixotic-spleen` in project `quixotic-spleen`: https://atlas.nomic.ai/map/db79b079-c5af-4296-9195-36eafcadbb90/9f86c512-9947-4fc5-a1e6-98446ba5a893
# 2023-07-03 11:34:57.933 | INFO     | nomic.atlas:map_embeddings:139 - quixotic-spleen: https://atlas.nomic.ai/map/db79b079-c5af-4296-9195-36eafcadbb90/9f86c512-9947-4fc5-a1e6-98446ba5a893

# %% [markdown]
# ## Reccommending Movies By Plot

# %%
from openai.embeddings_utils import distances_from_embeddings, indices_of_nearest_neighbors_from_distances

# %%
def print_recommendations_from_strings(
    strings,
    index_of_source_string,
    k_nearest_neighbors=3,
    model="text-embedding-ada-002"
):
    #Get all of the embeddings
    embeddings = [embedding_from_string(string) for string in strings]
    # get embedding for our specific query string
    query_embedding = embeddings[index_of_source_string]
    # get distances between our embedding and all other embeddings
    distances = distances_from_embeddings(query_embedding, embeddings)
    # get indices of the nearest neighbors
    indices_of_nearest_neighbors = indices_of_nearest_neighbors_from_distances(distances)
    
    query_string = strings[index_of_source_string]
    match_count = 0
    for i in indices_of_nearest_neighbors:
        if query_string == strings[i]:
            continue
        if match_count >= k_nearest_neighbors:
            break
        match_count += 1
        print(f"Found {match_count} closest match: ")
        print(f"Distance of: {distances[i]} ")
        print(strings[i])

# %%
print_recommendations_from_strings(movie_plots, 2)
# Out:
# Found 1 closest match:
# Distance of: 0.0844882078700182
# As a spacecraft departs a planet, a humanoid alien drinks an iridescent liquid and then dissolves. The remains of the alien cascade into a waterfall. The alien's DNA strands mix with the water.
# In 2089, archaeologists Elizabeth Shaw and Charlie Holloway discover a star map in Scotland that matches others from several unconnected ancient cultures. They interpret this as an invitation from humanity's forerunners, the "Engineers". Peter Weyland, the elderly CEO of Weyland Corporation, funds an expedition, aboard the scientific vessel Prometheus, to follow the map to the distant moon LV-223. The ship's crew travels in stasis while the android David monitors their voyage. Arriving in December 2093, mission-director Meredith Vickers informs them of their mission to find the Engineers and not to make contact without her permission.
# The Prometheus lands on the barren, mountainous surface near a large, artificial structure, which a team explores. Inside, they find stone cylinders, a monolithic statue of a humanoid head, and the decapitated corpse of a large alien, thought to be an Engineer; Shaw recovers its head. The crew finds other bodies, leading them to surmise the species is extinct. Crew members Millburn and Fifield grow uncomfortable with the discoveries and attempt to return to Prometheus, but become stranded in the structure when they get lost. The expedition is cut short when a storm forces the crew to return to the ship. David secretly takes a cylinder from the structure, while the remaining cylinders begin leaking a dark liquid. In the ship's lab, the Engineer's DNA is found to match that of humans. David investigates the cylinder and the liquid inside. He intentionally taints a drink with the liquid and gives it to the unsuspecting Holloway, who had stated he would do anything for answers. Shortly after, Shaw and Holloway have sex.
# Inside the structure, a snake-like creature kills Millburn and sprays a corrosive fluid that melts Fifield's helmet. Fifield falls face-first into a puddle of dark liquid. When the crew returns, they find Millburn's corpse. David separately discovers a control room containing a surviving Engineer in stasis, and a large 3D holographic star map highlighting Earth. Meanwhile, Holloway sickens rapidly. He is rushed back to Prometheus, but Vickers refuses to let him aboard, and at his urging, burns him to death with a flamethrower. Later, a medical scan reveals that Shaw, despite being sterile, is pregnant. Fearing the worst, she uses an automated surgery table to extract a squid-like creature from her abdomen. Shaw then discovers that Weyland has been in stasis aboard Prometheus. He explains that he wants to ask the Engineers to prevent his death from old age. As Weyland prepares to leave for the structure, Vickers addresses him as "Father".
# A monstrous, mutated Fifield returns to the Prometheus and kills several crew members before he is killed. The Prometheus' captain, Janek, speculates that the structure was an Engineer military base that lost control of a virulent biological weapon, the dark liquid. He also determines that the structure houses a spacecraft. Weyland and a team return to the structure, accompanied by Shaw. David wakes the Engineer from stasis and speaks to him in an attempt to explain what Weyland wants. The Engineer responds by decapitating David and killing Weyland and his team, before reactivating the spacecraft. Shaw flees and warns Janek that the Engineer is planning to release the liquid on Earth, convincing him to stop the spacecraft. Janek and the remaining crew sacrifice themselves by ramming the Prometheus into the alien craft, ejecting the lifeboat in the process, while Vickers flees in an escape pod. The Engineer's disabled spacecraft crashes onto the ground, killing Vickers. Shaw goes to the lifeboat and finds her alien offspring is alive and has grown to gigantic size. David's still-active head warns Shaw that the Engineer is pursuing her. The Engineer forces open the lifeboat's airlock and attacks Shaw, who releases her alien offspring onto the Engineer; it thrusts an ovipositor down the Engineer's throat, subduing him. Shaw recovers David's remains, and with his help, launches another Engineer spacecraft. She intends to reach the Engineers' homeworld in an attempt to understand why they wanted to destroy humanity.
# In the lifeboat, an alien creature bursts out of the Engineer's chest.
# Found 2 closest match:
# Distance of: 0.1362017052001545
# In 2004, a satellite detects a mysterious heat bloom beneath Bouvetøya, an island about one thousand miles off the coast of Antarctica. Wealthy industrialist Charles Bishop Weyland (Lance Henriksen) discovers through thermal imaging that there is a pyramid buried 2000 feet beneath the ice. He attempts to claim it for his multinational communications company, Weyland Industries, a subsidiary of the Weyland Corporation, and assembles a team of experts to investigate. The team includes archaeologists, linguistic experts, drillers, mercenaries, and a guide named Alexa Woods (Sanaa Lathan).
# As a Predator ship reaches Earth's orbit, it fires a beam that creates a passage through the ice towards the source of the heat bloom. When the team arrives at the abandoned whaling station above the heat source, they find the passage and descend beneath the ice. They locate the mysterious pyramid and begin to explore it, finding evidence of a prehistoric civilization and what appears to be a sacrificial chamber filled with human skeletons with ruptured rib cages.
# Meanwhile, three Predators consisting of Scar, Celtic and Chopper arrive and kill all the humans on the surface. They make their way down to the pyramid and arrive just as the team unwittingly activates the structure. The Alien Queen awakes from cryogenic stasis and begins to produce eggs. When the eggs hatch, several facehuggers attach themselves to humans trapped in the sacrificial chamber. Chestbursters emerge from the humans and quickly grow into adult Aliens. Conflict erupts between the Predators, Aliens, and humans, resulting in several deaths. Celtic and Chopper are killed by an Alien, and Weyland buys Alexa and Italian archaeologist Sebastian De Rosa (Raoul Bova) enough time to escape from Scar, giving his life in the process. The two witness Scar kill a facehugger and an Alien with a shuriken before unmasking and marking himself with the blood of the facehugger. After Alexa and Sebastian leave, another facehugger attaches itself to Scar due to him not wearing his mask.
# Through translation of the pyramid's hieroglyphs, Alexa and Sebastian learn that the Predators have been visiting Earth for thousands of years. It was they who taught early human civilizations how to build pyramids, and were worshiped as gods. Every 100 years they visited Earth to take part in a rite of passage by which several humans sacrifice themselves as hosts for the Aliens, creating the "ultimate prey" for the Predators to hunt while being able to survive in the pyramid; if overwhelmed, the Predators would activate a self-destruct device to eliminate the Aliens and themselves. The two deduce that this is why the current Predators are at the pyramid, and that the heat bloom was to attract humans for the sole purpose of making new Aliens to hunt.
# Alexa and Sebastian decide that the Predators must be allowed to succeed in their hunt so that the Aliens do not escape to the surface. Sebastian is captured by an Alien, leaving only Alexa and Scar to fight the Aliens. Scar uses parts of a dead Alien to fashion weapons for Alexa and the two form an alliance. The Queen Alien, using her acid blood, is freed from her restraints and begins pursuing, along with the other Aliens, Alexa and Scar. Just as they are about to escape, they use a self-destruct device to destroy the pyramid and the remaining Aliens. Alexa and Scar reach the surface, however the Alien Queen has survived and continues chasing them. They defeat the Queen by attaching its chain to a water tower and pushing her over a cliff, dragging the Queen to the ocean floor. Scar, however, had been impaled by the Alien Queen's tail and succumbs to his wounds and dies.
# A Predator ship uncloaks and several Predators appear. They retrieve their fallen comrade and an elite Predator presents Alexa with one of their spear weapons as a gift. The other Predators recognize her for her skill as a warrior symbolized by the alien blood Scar burned on her cheek before he died. As the Predators retreat into space, a chestburster with a hybrid form of an Alien and a Predator erupts from Scar's chest.
# Found 3 closest match:
# Distance of: 0.13664061546949713
# In the near future, the unmanned Pilgrim 7 space probe returns from Mars to Earth orbit with soil samples potentially containing evidence of extraterrestrial life. The probe is captured and its samples retrieved by the International Space Station and its six-member crew. Exobiologist Hugh Derry, who is paralyzed from the waist down, revives a dormant cell from the sample, which quickly grows into a multi-celled organism that American school children name "Calvin". Hugh realizes that Calvin's cells can change their specialisation, acting as muscle, sensor, and neuron cells all at once.
# An accident in the lab causes Calvin to become dormant; Hugh attempts to revive Calvin with electric shocks, but Calvin immediately becomes hostile and attacks Hugh, crushing his hand. While Hugh lies unconscious from Calvin's attack, Calvin uses Hugh's electric shock tool to escape its enclosure; now free in the laboratory, Calvin devours a lab rat by absorbing it, growing in size. Engineer Rory Adams enters the lab to rescue Hugh; he is locked in by fellow crew member and physician David Jordan, however, to keep Calvin contained. Calvin latches onto Rory's leg; after Rory unsuccessfully attacks Calvin with a portable rocket thruster, Calvin enters his mouth, devouring his organs from the inside and killing him. Emerging from Rory's mouth even larger, Calvin escapes through a fire-control vent.
# Finding their communication with Earth cut off due to overheating of the communication systems, ISS commander Ekaterina Golovkina performs a space walk to find and fix the problem. She discovers that Calvin has breached the ISS's cooling system; soon after, Calvin attacks her, rupturing her spacesuit's water coolant system in the process and causing the water in the system to fill her suit. She blindly makes her way back to the airlock; however, she and the crew realize that if she re-enters, Calvin will also be able to re-enter the ISS. Hence, she refuses to open the hatch and stops David from helping her do so; this keeps Calvin out of the station for the time being but also causes her to drown and die in her spacesuit.
# Calvin then attempts to re-enter the station through its maneuvering thrusters. The crew try to fire the thrusters to blast Calvin away from the spacecraft, but their attempts fail, using up too much fuel and causing the ISS to enter a decaying orbit where it will burn up in Earth's atmosphere. Pilot Sho Murakami informs the crew that they need to use the station's remaining fuel to get back into a safe orbit, although this allows Calvin to re-enter the station. The crew plan to make Calvin dormant by sealing themselves into one module and venting the atmosphere from the rest of the station.
# After the remaining crew finalize preparations to do so, Hugh enters cardiac arrest. The crew then discover that Calvin has been feeding off of Hugh's paralyzed leg. Calvin attacks the remainder of the crew; Sho seals himself in a sleeping pod. As Calvin attempts to break its glass, David and the quarantine officer Miranda North use Hugh's corpse as bait to lure Calvin away from Sho and trap it in another module to deprive it of oxygen. Having received a distress call prior to the damage to the ISS's communication system, Earth sends a Soyuz spacecraft to the station as a fail-safe plan to push the station into deep space. Believing the Soyuz to be on a rescue mission for the ISS crew, Sho leaves his pod and moves to board it, forcing open its hatch; Calvin then attacks him and the Soyuz crew, causing the craft's docking mechanism to fail and resulting in the capsule crashing into the ISS, killing Sho and the Soyuz crew and causing the ISS to once again enter a decaying orbit.
# The only two remaining survivors, David and Miranda, aware that Calvin could survive re-entry, plan for David to lure Calvin into one of the two remaining escape pods attached to the ISS for David to manually pilot the pod into deep space, isolating Calvin and allowing Miranda to return to Earth in the second pod. David manages to lure Calvin into his pod while Miranda enters her pod; as they simultaneously undock their pods from the ISS, one of the pods hits debris and is damaged, veering off course. In David's pod, Calvin attacks him as he struggles to manually pilot the pod; in Miranda's pod, she records a black box message in case of her death during re-entry informing the world of her colleagues' deaths and not to trust Calvin nor any extraterrestrial life from Mars as well as to destroy Calvin at any cost should he make his way to Earth.
# The two pods separate, one earthbound, the other spiraling away from Earth. The earthbound pod lands in the ocean; two nearby Vietnamese fishermen approach it. As they look into the pod, it is revealed to be David's, the astronaut now encased in a web-like substance. Meanwhile, Miranda's pod's navigation system fails due to damage sustained from the debris, sending her flying away from Earth out of control, much to her horror. On Earth, despite David attempting to warn the fishermen, the fishermen open the pod's hatch. Meanwhile, more boats arrive.
